# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Path to the folder containing the datasets
folder_path = 'Datasets/World Bank'

# Initialize an empty DataFrame to collect all data
final_df = None

# Loop through each file in the directory
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        
        # Read each CSV file, assuming the first four rows are headers and need to be skipped
        df = pd.read_csv(file_path, skiprows=4)
        # Check if 'Country Name' and 'Indicator Name' are in columns
        if 'Country Name' in df.columns and 'Indicator Name' in df.columns:
            # Get the name of the indicator for this dataset
            indicator_name = df.at[0, 'Indicator Name']
            
            # Filter columns for 'Country Name' and all years
            cols_to_keep = ['Country Name'] + [col for col in df.columns if col.isdigit()]
            df = df[cols_to_keep]
            
            # Reshape the DataFrame
            df_reshaped = pd.melt(df, id_vars='Country Name', var_name='Year', value_name=indicator_name)
            #print(df_reshaped.shape)
            # If final_df is not initialized, initialize it with the first reshaped DataFrame
            if final_df is None:
                final_df = df_reshaped
            else:
                # Merge the new DataFrame with the existing final_df on 'Country Name' and 'Year'
                final_df = pd.merge(final_df, df_reshaped, on=['Country Name', 'Year'], how='outer')


final_df
# Out:
#                       Country Name  Year  \
# 0                            Aruba  1960
# 1      Africa Eastern and Southern  1960
# 2                      Afghanistan  1960
# 3       Africa Western and Central  1960
# 4                           Angola  1960
# ...                            ...   ...
# 17019                       Kosovo  2023
# 17020                  Yemen, Rep.  2023
# 17021                 South Africa  2023
# 17022                       Zambia  2023
# 17023                     Zimbabwe  2023
#
#        Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17019                                                NaN
# 17020                                                NaN
# 17021                                                NaN
# 17022                                                NaN
# 17023                                                NaN
#
#        Access to electricity (% of population)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 17019                                      NaN
# 17020                                      NaN
# 17021                                      NaN
# 17022                                      NaN
# 17023                                      NaN
#
#        People using safely managed drinking water services (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17019                                                NaN
# 17020                                                NaN
# 17021                                                NaN
# 17022                                                NaN
# 17023                                                NaN
#
#        Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17019                                                NaN
# 17020                                                NaN
# 17021                                                NaN
# 17022                                                NaN
# 17023                                                NaN
#
#        CO2 emissions (metric tons per capita)  GDP per capita (current US$)  \
# 0                                         NaN                           NaN
# 1                                         NaN                    141.385955
# 2                                         NaN                     62.369375
# 3                                         NaN                    107.053706
# 4                                         NaN                           NaN
# ...                                       ...                           ...
# 17019                                     NaN                           NaN
# 17020                                     NaN                           NaN
# 17021                                     NaN                           NaN
# 17022                                     NaN                           NaN
# 17023                                     NaN                           NaN
#
#        GNI (current US$)  Current health expenditure per capita (current US$)  \
# 0                    NaN                                                NaN
# 1           1.713262e+10                                                NaN
# 2           5.488888e+08                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 17019                NaN                                                NaN
# 17020                NaN                                                NaN
# 17021                NaN                                                NaN
# 17022                NaN                                                NaN
# 17023                NaN                                                NaN
#
#        ...  Mortality rate, under-5 (per 1,000 live births)  \
# 0      ...                                              NaN
# 1      ...                                              NaN
# 2      ...                                            357.3
# 3      ...                                              NaN
# 4      ...                                              NaN
# ...    ...                                              ...
# 17019  ...                                              NaN
# 17020  ...                                              NaN
# 17021  ...                                              NaN
# 17022  ...                                              NaN
# 17023  ...                                              NaN
#
#        Physicians (per 1,000 people)  \
# 0                                NaN
# 1                                NaN
# 2                              0.035
# 3                                NaN
# 4                              0.067
# ...                              ...
# 17019                            NaN
# 17020                            NaN
# 17021                            NaN
# 17022                            NaN
# 17023                            NaN
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17019                                                NaN
# 17020                                                NaN
# 17021                                                NaN
# 17022                                                NaN
# 17023                                                NaN
#
#        Population, total  \
# 0                54608.0
# 1            130692579.0
# 2              8622466.0
# 3             97256290.0
# 4              5357195.0
# ...                  ...
# 17019                NaN
# 17020                NaN
# 17021                NaN
# 17022                NaN
# 17023                NaN
#
#        Poverty headcount ratio at societal poverty line (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17019                                                NaN
# 17020                                                NaN
# 17021                                                NaN
# 17022                                                NaN
# 17023                                                NaN
#
#        Prevalence of current tobacco use (% of adults)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 17019                                              NaN
# 17020                                              NaN
# 17021                                              NaN
# 17022                                              NaN
# 17023                                              NaN
#
#        Prevalence of undernourishment (% of population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 17019                                               NaN
# 17020                                               NaN
# 17021                                               NaN
# 17022                                               NaN
# 17023                                               NaN
#
#        People using safely managed sanitation services (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17019                                                NaN
# 17020                                                NaN
# 17021                                                NaN
# 17022                                                NaN
# 17023                                                NaN
#
#        Suicide mortality rate (per 100,000 population)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 17019                                              NaN
# 17020                                              NaN
# 17021                                              NaN
# 17022                                              NaN
# 17023                                              NaN
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17019                                                NaN
# 17020                                             17.533
# 17021                                             28.396
# 17022                                              4.220
# 17023                                              9.116
#
# [17024 rows x 29 columns]

# %%
print(final_df.dtypes)
# Out:
# Country Name                                                                                             object
# Year                                                                                                     object
# Access to clean fuels and technologies for cooking (% of population)                                    float64
# Access to electricity (% of population)                                                                 float64
# People using safely managed drinking water services (% of population)                                   float64
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)    float64
# CO2 emissions (metric tons per capita)                                                                  float64
# GDP per capita (current US$)                                                                            float64
# GNI (current US$)                                                                                       float64
# Current health expenditure per capita (current US$)                                                     float64
# Immunization, DPT (% of children ages 12-23 months)                                                     float64
# Immunization, HepB3 (% of one-year-old children)                                                        float64
# Immunization, measles (% of children ages 12-23 months)                                                 float64
# Life expectancy at birth, total (years)                                                                 float64
# Hospital beds (per 1,000 people)                                                                        float64
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                            float64
# Mortality rate, adult, female (per 1,000 female adults)                                                 float64
# Mortality rate, adult, male (per 1,000 male adults)                                                     float64
# Mortality caused by road traffic injury (per 100,000 population)                                        float64
# Mortality rate, under-5 (per 1,000 live births)                                                         float64
# Physicians (per 1,000 people)                                                                           float64
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                  float64
# Population, total                                                                                       float64
# Poverty headcount ratio at societal poverty line (% of population)                                      float64
# Prevalence of current tobacco use (% of adults)                                                         float64
# Prevalence of undernourishment (% of population)                                                        float64
# People using safely managed sanitation services (% of population)                                       float64
# Suicide mortality rate (per 100,000 population)                                                         float64
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                     float64
# dtype: object

# %%
final_df['Year'] = final_df['Year'].astype(int)

# %%
final_df = final_df.dropna(subset=['Life expectancy at birth, total (years)'])
final_df.reset_index(drop=True, inplace=True)
final_df
# Out:
#                       Country Name  Year  \
# 0                            Aruba  1960
# 1      Africa Eastern and Southern  1960
# 2                      Afghanistan  1960
# 3       Africa Western and Central  1960
# 4                           Angola  1960
# ...                            ...   ...
# 15861                       Kosovo  2021
# 15862                  Yemen, Rep.  2021
# 15863                 South Africa  2021
# 15864                       Zambia  2021
# 15865                     Zimbabwe  2021
#
#        Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15861                                                NaN
# 15862                                               61.3
# 15863                                               88.4
# 15864                                               10.2
# 15865                                               30.3
#
#        Access to electricity (% of population)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 15861                                      NaN
# 15862                                74.877197
# 15863                                89.300000
# 15864                                46.685116
# 15865                                48.979927
#
#        People using safely managed drinking water services (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15861                                                NaN
# 15862                                                NaN
# 15863                                                NaN
# 15864                                                NaN
# 15865                                          26.476995
#
#        Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15861                                                NaN
# 15862                                                NaN
# 15863                                                NaN
# 15864                                                NaN
# 15865                                                NaN
#
#        CO2 emissions (metric tons per capita)  GDP per capita (current US$)  \
# 0                                         NaN                           NaN
# 1                                         NaN                    141.385955
# 2                                         NaN                     62.369375
# 3                                         NaN                    107.053706
# 4                                         NaN                           NaN
# ...                                       ...                           ...
# 15861                                     NaN                   5269.783901
# 15862                                     NaN                    543.637538
# 15863                                     NaN                   7073.612754
# 15864                                     NaN                   1134.713454
# 15865                                     NaN                   1773.920411
#
#        GNI (current US$)  Current health expenditure per capita (current US$)  \
# 0                    NaN                                                NaN
# 1           1.713262e+10                                                NaN
# 2           5.488888e+08                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 15861       9.591067e+09                                                NaN
# 15862                NaN                                                NaN
# 15863       4.120891e+11                                                NaN
# 15864       2.209643e+10                                                NaN
# 15865       2.772683e+10                                                NaN
#
#        ...  Mortality rate, under-5 (per 1,000 live births)  \
# 0      ...                                              NaN
# 1      ...                                              NaN
# 2      ...                                            357.3
# 3      ...                                              NaN
# 4      ...                                              NaN
# ...    ...                                              ...
# 15861  ...                                             10.0
# 15862  ...                                             61.9
# 15863  ...                                             32.8
# 15864  ...                                             57.7
# 15865  ...                                             49.5
#
#        Physicians (per 1,000 people)  \
# 0                                NaN
# 1                                NaN
# 2                              0.035
# 3                                NaN
# 4                              0.067
# ...                              ...
# 15861                            NaN
# 15862                            NaN
# 15863                          0.809
# 15864                          0.297
# 15865                            NaN
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15861                                                NaN
# 15862                                                NaN
# 15863                                                NaN
# 15864                                                NaN
# 15865                                                NaN
#
#        Population, total  \
# 0                54608.0
# 1            130692579.0
# 2              8622466.0
# 3             97256290.0
# 4              5357195.0
# ...                  ...
# 15861          1786038.0
# 15862         32981641.0
# 15863         59392255.0
# 15864         19473125.0
# 15865         15993524.0
#
#        Poverty headcount ratio at societal poverty line (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15861                                                NaN
# 15862                                                NaN
# 15863                                                NaN
# 15864                                                NaN
# 15865                                                NaN
#
#        Prevalence of current tobacco use (% of adults)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 15861                                              NaN
# 15862                                              NaN
# 15863                                              NaN
# 15864                                              NaN
# 15865                                              NaN
#
#        Prevalence of undernourishment (% of population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 15861                                               NaN
# 15862                                              34.5
# 15863                                               7.9
# 15864                                              29.8
# 15865                                              38.4
#
#        People using safely managed sanitation services (% of population)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15861                                                NaN
# 15862                                          19.101356
# 15863                                          70.991768
# 15864                                                NaN
# 15865                                          31.802437
#
#        Suicide mortality rate (per 100,000 population)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 15861                                              NaN
# 15862                                              NaN
# 15863                                              NaN
# 15864                                              NaN
# 15865                                              NaN
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 15861                                                NaN
# 15862                                             18.647
# 15863                                             28.770
# 15864                                              5.200
# 15865                                              9.540
#
# [15866 rows x 29 columns]

# %%
nan_colcounts = final_df.isna().sum()/final_df.shape[0] * 100
print(nan_colcounts)
# Out:
# Country Name                                                                                             0.000000
# Year                                                                                                     0.000000
# Access to clean fuels and technologies for cooking (% of population)                                    67.679314
# Access to electricity (% of population)                                                                 54.922476
# People using safely managed drinking water services (% of population)                                   78.356233
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)    92.650952
# CO2 emissions (metric tons per capita)                                                                  53.699735
# GDP per capita (current US$)                                                                            20.086978
# GNI (current US$)                                                                                       26.812051
# Current health expenditure per capita (current US$)                                                     69.330644
# Immunization, DPT (% of children ages 12-23 months)                                                     41.220219
# Immunization, HepB3 (% of one-year-old children)                                                        63.683348
# Immunization, measles (% of children ages 12-23 months)                                                 41.945040
# Life expectancy at birth, total (years)                                                                  0.000000
# Hospital beds (per 1,000 people)                                                                        69.507122
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                            70.881129
# Mortality rate, adult, female (per 1,000 female adults)                                                  1.361402
# Mortality rate, adult, male (per 1,000 male adults)                                                      1.361402
# Mortality caused by road traffic injury (per 100,000 population)                                        70.855918
# Mortality rate, under-5 (per 1,000 live births)                                                         21.454683
# Physicians (per 1,000 people)                                                                           68.498676
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                  78.620950
# Population, total                                                                                        0.000000
# Poverty headcount ratio at societal poverty line (% of population)                                      83.845960
# Prevalence of current tobacco use (% of adults)                                                         90.810538
# Prevalence of undernourishment (% of population)                                                        71.208874
# People using safely managed sanitation services (% of population)                                       75.784697
# Suicide mortality rate (per 100,000 population)                                                         70.881129
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                     54.084205
# dtype: float64

# %%
nan_yearcounts = final_df.isna().groupby(final_df['Year']).sum()
plt.figure(figsize=(10, 6))
nan_yearcounts.sum(axis=1).plot(kind='bar')  # Summing NaN counts across all columns for each year
plt.title('Count of NaN Values Per Year')
plt.xlabel('Year')
plt.ylabel('Number of NaN Values')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
final_df = final_df[(final_df['Year'] >= 2000) & (final_df['Year'] <= 2019)]
final_df
# Out:
#                       Country Name  Year  \
# 10192                        Aruba  2000
# 10193  Africa Eastern and Southern  2000
# 10194                  Afghanistan  2000
# 10195   Africa Western and Central  2000
# 10196                       Angola  2000
# ...                            ...   ...
# 15347                       Kosovo  2019
# 15348                  Yemen, Rep.  2019
# 15349                 South Africa  2019
# 15350                       Zambia  2019
# 15351                     Zimbabwe  2019
#
#        Access to clean fuels and technologies for cooking (% of population)  \
# 10192                                                NaN
# 10193                                          11.580366
# 10194                                           6.700000
# 10195                                           4.804413
# 10196                                          40.100000
# ...                                                  ...
# 15347                                                NaN
# 15348                                          61.400000
# 15349                                          87.100000
# 15350                                          11.500000
# 15351                                          30.200000
#
#        Access to electricity (% of population)  \
# 10192                                91.660398
# 10193                                19.957302
# 10194                                 4.446891
# 10195                                34.137971
# 10196                                24.238865
# ...                                        ...
# 15347                                      NaN
# 15348                                72.776573
# 15349                                85.000000
# 15350                                43.000000
# 15351                                46.682095
#
#        People using safely managed drinking water services (% of population)  \
# 10192                                                NaN
# 10193                                                NaN
# 10194                                          11.093326
# 10195                                          13.470213
# 10196                                                NaN
# ...                                                  ...
# 15347                                                NaN
# 15348                                                NaN
# 15349                                                NaN
# 15350                                                NaN
# 15351                                          26.683978
#
#        Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 10192                                                NaN
# 10193                                           5.433571
# 10194                                           0.002770
# 10195                                           5.716938
# 10196                                           5.186320
# ...                                                  ...
# 15347                                                NaN
# 15348                                           0.027780
# 15349                                           8.766210
# 15350                                           3.851760
# 15351                                           3.628090
#
#        CO2 emissions (metric tons per capita)  GDP per capita (current US$)  \
# 10192                                     NaN                  21026.167091
# 10193                                0.891352                    710.665706
# 10194                                0.055167                           NaN
# 10195                                0.521689                    519.757395
# 10196                                0.988416                    556.884244
# ...                                       ...                           ...
# 15347                                     NaN                   4416.029253
# 15348                                0.354864                    693.816504
# 15349                                7.688908                   6702.526617
# 15350                                0.414336                   1268.120941
# 15351                                0.663338                   1421.868596
#
#        GNI (current US$)  Current health expenditure per capita (current US$)  \
# 10192       1.849411e+09                                                NaN
# 10193       2.726089e+11                                          43.717514
# 10194                NaN                                                NaN
# 10195                NaN                                          20.182081
# 10196       7.448735e+09                                          13.000087
# ...                  ...                                                ...
# 15347       8.079554e+09                                                NaN
# 15348                NaN                                                NaN
# 15349       3.796119e+11                                         550.480225
# 15350       2.290408e+10                                          67.457771
# 15351       2.144526e+10                                          54.808506
#
#        ...  Mortality rate, under-5 (per 1,000 live births)  \
# 10192  ...                                              NaN
# 10193  ...                                       138.180235
# 10194  ...                                       129.300000
# 10195  ...                                       169.207126
# 10196  ...                                       205.100000
# ...    ...                                              ...
# 15347  ...                                        11.200000
# 15348  ...                                        61.600000
# 15349  ...                                        34.300000
# 15350  ...                                        62.600000
# 15351  ...                                        52.700000
#
#        Physicians (per 1,000 people)  \
# 10192                            NaN
# 10193                            NaN
# 10194                            NaN
# 10195                       0.192177
# 10196                            NaN
# ...                              ...
# 15347                            NaN
# 15348                            NaN
# 15349                       0.799000
# 15350                       0.239000
# 15351                            NaN
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 10192                                                NaN
# 10193                                          31.359177
# 10194                                          51.554534
# 10195                                          66.123679
# 10196                                          28.133895
# ...                                                  ...
# 15347                                                NaN
# 15348                                          44.466967
# 15349                                          28.674754
# 15350                                          25.925460
# 15351                                          20.834700
#
#        Population, total  \
# 10192            89101.0
# 10193        401600588.0
# 10194         19542982.0
# 10195        269611898.0
# 10196         16394062.0
# ...                  ...
# 15347          1788878.0
# 15348         31546691.0
# 15349         58087055.0
# 15350         18380477.0
# 15351         15354608.0
#
#        Poverty headcount ratio at societal poverty line (% of population)  \
# 10192                                                NaN
# 10193                                                NaN
# 10194                                                NaN
# 10195                                                NaN
# 10196                                               37.2
# ...                                                  ...
# 15347                                                NaN
# 15348                                                NaN
# 15349                                                NaN
# 15350                                                NaN
# 15351                                               46.7
#
#        Prevalence of current tobacco use (% of adults)  \
# 10192                                              NaN
# 10193                                        21.206918
# 10194                                        36.900000
# 10195                                        12.780393
# 10196                                              NaN
# ...                                                ...
# 15347                                              NaN
# 15348                                        20.500000
# 15349                                        20.400000
# 15350                                        14.600000
# 15351                                        12.100000
#
#        Prevalence of undernourishment (% of population)  \
# 10192                                               NaN
# 10193                                               NaN
# 10194                                               NaN
# 10195                                               NaN
# 10196                                               NaN
# ...                                                 ...
# 15347                                               NaN
# 15348                                              38.9
# 15349                                               6.1
# 15350                                              29.2
# 15351                                              38.9
#
#        People using safely managed sanitation services (% of population)  \
# 10192                                                NaN
# 10193                                          18.819772
# 10194                                                NaN
# 10195                                          14.165457
# 10196                                                NaN
# ...                                                  ...
# 15347                                                NaN
# 15348                                          18.568462
# 15349                                          69.539835
# 15350                                                NaN
# 15351                                          32.961481
#
#        Suicide mortality rate (per 100,000 population)  \
# 10192                                              NaN
# 10193                                        10.942055
# 10194                                         4.900000
# 10195                                         6.806788
# 10196                                         8.700000
# ...                                                ...
# 15347                                              NaN
# 15348                                         5.800000
# 15349                                        23.500000
# 15350                                         7.300000
# 15351                                        14.100000
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)
# 10192                                                NaN
# 10193                                           7.470911
# 10194                                           7.942000
# 10195                                           4.767679
# 10196                                          16.562000
# ...                                                  ...
# 15347                                                NaN
# 15348                                          17.350000
# 15349                                          25.540000
# 15350                                           5.540000
# 15351                                           7.370000
#
# [5160 rows x 29 columns]

# %%
nan_colcounts = final_df.isna().sum()/final_df.shape[0] * 100
print(nan_colcounts)
# Out:
# Country Name                                                                                             0.000000
# Year                                                                                                     0.000000
# Access to clean fuels and technologies for cooking (% of population)                                     9.651163
# Access to electricity (% of population)                                                                  0.872093
# People using safely managed drinking water services (% of population)                                   39.534884
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)    77.403101
# CO2 emissions (metric tons per capita)                                                                   8.100775
# GDP per capita (current US$)                                                                             3.294574
# GNI (current US$)                                                                                        6.356589
# Current health expenditure per capita (current US$)                                                     10.562016
# Immunization, DPT (% of children ages 12-23 months)                                                      8.468992
# Immunization, HepB3 (% of one-year-old children)                                                        19.651163
# Immunization, measles (% of children ages 12-23 months)                                                  8.468992
# Life expectancy at birth, total (years)                                                                  0.000000
# Hospital beds (per 1,000 people)                                                                        48.720930
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                            10.465116
# Mortality rate, adult, female (per 1,000 female adults)                                                  1.317829
# Mortality rate, adult, male (per 1,000 male adults)                                                      1.317829
# Mortality caused by road traffic injury (per 100,000 population)                                        10.387597
# Mortality rate, under-5 (per 1,000 live births)                                                          6.937984
# Physicians (per 1,000 people)                                                                           54.399225
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                  43.682171
# Population, total                                                                                        0.000000
# Poverty headcount ratio at societal poverty line (% of population)                                      66.414729
# Prevalence of current tobacco use (% of adults)                                                         75.775194
# Prevalence of undernourishment (% of population)                                                        19.961240
# People using safely managed sanitation services (% of population)                                       32.286822
# Suicide mortality rate (per 100,000 population)                                                         10.465116
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                      8.914729
# dtype: float64

# %%
nan_rowcounts = final_df.isna().sum(axis=1)/final_df.shape[1] * 100
print(nan_rowcounts)
plt.figure(figsize=(10, 6))
plt.hist(nan_rowcounts, bins=list(range(0, 101, 5)), color='skyblue', edgecolor='black')
plt.title('Histogram of Missing Value Percentages per Row')
plt.xlabel('Percentage of Missing Values')
plt.ylabel('Number of Rows')
plt.grid(True)
plt.show()
# Out:
# 10192    68.965517
# 10193    17.241379
# 10194    27.586207
# 10195    13.793103
# 10196    24.137931
#            ...
# 15347    68.965517
# 15348    20.689655
# 15349    10.344828
# 15350    13.793103
# 15351     6.896552
# Length: 5160, dtype: float64

# %%
final_df = final_df[nan_rowcounts < 25].copy()
final_df
# Out:
#                       Country Name  Year  \
# 10193  Africa Eastern and Southern  2000
# 10195   Africa Western and Central  2000
# 10196                       Angola  2000
# 10197                      Albania  2000
# 10198                   Arab World  2000
# ...                            ...   ...
# 15346                        Samoa  2019
# 15348                  Yemen, Rep.  2019
# 15349                 South Africa  2019
# 15350                       Zambia  2019
# 15351                     Zimbabwe  2019
#
#        Access to clean fuels and technologies for cooking (% of population)  \
# 10193                                          11.580366
# 10195                                           4.804413
# 10196                                          40.100000
# 10197                                          38.700000
# 10198                                          74.998725
# ...                                                  ...
# 15346                                          35.300000
# 15348                                          61.400000
# 15349                                          87.100000
# 15350                                          11.500000
# 15351                                          30.200000
#
#        Access to electricity (% of population)  \
# 10193                                19.957302
# 10195                                34.137971
# 10196                                24.238865
# 10197                                99.430855
# 10198                                81.108851
# ...                                        ...
# 15346                                99.200000
# 15348                                72.776573
# 15349                                85.000000
# 15350                                43.000000
# 15351                                46.682095
#
#        People using safely managed drinking water services (% of population)  \
# 10193                                                NaN
# 10195                                          13.470213
# 10196                                                NaN
# 10197                                          49.138321
# 10198                                                NaN
# ...                                                  ...
# 15346                                          62.075643
# 15348                                                NaN
# 15349                                                NaN
# 15350                                                NaN
# 15351                                          26.683978
#
#        Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 10193                                           5.433571
# 10195                                           5.716938
# 10196                                           5.186320
# 10197                                           4.431000
# 10198                                           0.369289
# ...                                                  ...
# 15346                                           2.390540
# 15348                                           0.027780
# 15349                                           8.766210
# 15350                                           3.851760
# 15351                                           3.628090
#
#        CO2 emissions (metric tons per capita)  GDP per capita (current US$)  \
# 10193                                0.891352                    710.665706
# 10195                                0.521689                    519.757395
# 10196                                0.988416                    556.884244
# 10197                                1.031568                   1126.683340
# 10198                                3.253567                   2858.484294
# ...                                       ...                           ...
# 15346                                1.315212                   4308.300729
# 15348                                0.354864                    693.816504
# 15349                                7.688908                   6702.526617
# 15350                                0.414336                   1268.120941
# 15351                                0.663338                   1421.868596
#
#        GNI (current US$)  Current health expenditure per capita (current US$)  \
# 10193       2.726089e+11                                          43.717514
# 10195                NaN                                          20.182081
# 10196       7.448735e+09                                          13.000087
# 10197       3.585007e+09                                          65.149994
# 10198       8.012759e+11                                         111.535562
# ...                  ...                                                ...
# 15346       8.771328e+08                                         239.131958
# 15348                NaN                                                NaN
# 15349       3.796119e+11                                         550.480225
# 15350       2.290408e+10                                          67.457771
# 15351       2.144526e+10                                          54.808506
#
#        ...  Mortality rate, under-5 (per 1,000 live births)  \
# 10193  ...                                       138.180235
# 10195  ...                                       169.207126
# 10196  ...                                       205.100000
# 10197  ...                                        27.200000
# 10198  ...                                        59.999412
# ...    ...                                              ...
# 15346  ...                                        17.500000
# 15348  ...                                        61.600000
# 15349  ...                                        34.300000
# 15350  ...                                        62.600000
# 15351  ...                                        52.700000
#
#        Physicians (per 1,000 people)  \
# 10193                            NaN
# 10195                       0.192177
# 10196                            NaN
# 10197                       1.359000
# 10198                       1.187473
# ...                              ...
# 15346                            NaN
# 15348                            NaN
# 15349                       0.799000
# 15350                       0.239000
# 15351                            NaN
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 10193                                          31.359177
# 10195                                          66.123679
# 10196                                          28.133895
# 10197                                          24.302869
# 10198                                          49.011025
# ...                                                  ...
# 15346                                          11.014834
# 15348                                          44.466967
# 15349                                          28.674754
# 15350                                          25.925460
# 15351                                          20.834700
#
#        Population, total  \
# 10193        401600588.0
# 10195        269611898.0
# 10196         16394062.0
# 10197          3089027.0
# 10198        287065982.0
# ...                  ...
# 15346           211905.0
# 15348         31546691.0
# 15349         58087055.0
# 15350         18380477.0
# 15351         15354608.0
#
#        Poverty headcount ratio at societal poverty line (% of population)  \
# 10193                                                NaN
# 10195                                                NaN
# 10196                                               37.2
# 10197                                                NaN
# 10198                                                NaN
# ...                                                  ...
# 15346                                                NaN
# 15348                                                NaN
# 15349                                                NaN
# 15350                                                NaN
# 15351                                               46.7
#
#        Prevalence of current tobacco use (% of adults)  \
# 10193                                        21.206918
# 10195                                        12.780393
# 10196                                              NaN
# 10197                                        35.000000
# 10198                                        23.429855
# ...                                                ...
# 15346                                        25.900000
# 15348                                        20.500000
# 15349                                        20.400000
# 15350                                        14.600000
# 15351                                        12.100000
#
#        Prevalence of undernourishment (% of population)  \
# 10193                                               NaN
# 10195                                               NaN
# 10196                                               NaN
# 10197                                               NaN
# 10198                                               NaN
# ...                                                 ...
# 15346                                               7.4
# 15348                                              38.9
# 15349                                               6.1
# 15350                                              29.2
# 15351                                              38.9
#
#        People using safely managed sanitation services (% of population)  \
# 10193                                          18.819772
# 10195                                          14.165457
# 10196                                                NaN
# 10197                                          26.566859
# 10198                                          49.857270
# ...                                                  ...
# 15346                                          44.535084
# 15348                                          18.568462
# 15349                                          69.539835
# 15350                                                NaN
# 15351                                          32.961481
#
#        Suicide mortality rate (per 100,000 population)  \
# 10193                                        10.942055
# 10195                                         6.806788
# 10196                                         8.700000
# 10197                                         4.900000
# 10198                                         4.569915
# ...                                                ...
# 15346                                        12.600000
# 15348                                         5.800000
# 15349                                        23.500000
# 15350                                         7.300000
# 15351                                        14.100000
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)
# 10193                                           7.470911
# 10195                                           4.767679
# 10196                                          16.562000
# 10197                                          19.028000
# 10198                                          12.346092
# ...                                                  ...
# 15346                                           9.584000
# 15348                                          17.350000
# 15349                                          25.540000
# 15350                                           5.540000
# 15351                                           7.370000
#
# [4284 rows x 29 columns]

# %%
final_df.sort_values(by=['Country Name', 'Year'], inplace=True)

# List of columns not to interpolate
exclude_columns = ['Country Name', 'Year', 'Life expectancy at birth, total (years)']

# Iterate over each column that needs interpolation
for attribute in final_df.columns:
    if attribute not in exclude_columns:
        # Interpolate per group, ensuring the result aligns with the original DataFrame index
        final_df[attribute] = final_df.groupby('Country Name')[attribute].transform(lambda group: group.interpolate())


nan_colcounts = final_df.isna().sum()/final_df.shape[0] * 100
print(nan_colcounts)
# Out:
# Country Name                                                                                             0.000000
# Year                                                                                                     0.000000
# Access to clean fuels and technologies for cooking (% of population)                                     1.353875
# Access to electricity (% of population)                                                                  0.046685
# People using safely managed drinking water services (% of population)                                   33.660131
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)     0.373483
# CO2 emissions (metric tons per capita)                                                                   0.000000
# GDP per capita (current US$)                                                                             0.116713
# GNI (current US$)                                                                                        1.027077
# Current health expenditure per capita (current US$)                                                      0.676937
# Immunization, DPT (% of children ages 12-23 months)                                                      0.000000
# Immunization, HepB3 (% of one-year-old children)                                                        10.504202
# Immunization, measles (% of children ages 12-23 months)                                                  0.000000
# Life expectancy at birth, total (years)                                                                  0.000000
# Hospital beds (per 1,000 people)                                                                        11.064426
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                             0.023343
# Mortality rate, adult, female (per 1,000 female adults)                                                  0.000000
# Mortality rate, adult, male (per 1,000 male adults)                                                      0.000000
# Mortality caused by road traffic injury (per 100,000 population)                                         0.023343
# Mortality rate, under-5 (per 1,000 live births)                                                          0.000000
# Physicians (per 1,000 people)                                                                            8.053221
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                   0.093371
# Population, total                                                                                        0.000000
# Poverty headcount ratio at societal poverty line (% of population)                                      34.173669
# Prevalence of current tobacco use (% of adults)                                                          9.150327
# Prevalence of undernourishment (% of population)                                                        10.527544
# People using safely managed sanitation services (% of population)                                       22.549020
# Suicide mortality rate (per 100,000 population)                                                          0.023343
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                      1.190476
# dtype: float64

# %%
for attribute in final_df.columns:
    if attribute not in exclude_columns:
        # Use direct methods ffill() and bfill() and ensure the index aligns with the DataFrame
        final_df[attribute] = final_df.groupby('Country Name')[attribute].transform(
            lambda group: group.ffill().bfill()
        )
nan_colcounts = final_df.isna().sum()/final_df.shape[0] * 100
print(nan_colcounts)
# Out:
# Country Name                                                                                             0.000000
# Year                                                                                                     0.000000
# Access to clean fuels and technologies for cooking (% of population)                                     1.353875
# Access to electricity (% of population)                                                                  0.000000
# People using safely managed drinking water services (% of population)                                   32.983193
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)     0.000000
# CO2 emissions (metric tons per capita)                                                                   0.000000
# GDP per capita (current US$)                                                                             0.093371
# GNI (current US$)                                                                                        0.093371
# Current health expenditure per capita (current US$)                                                      0.256769
# Immunization, DPT (% of children ages 12-23 months)                                                      0.000000
# Immunization, HepB3 (% of one-year-old children)                                                         2.334267
# Immunization, measles (% of children ages 12-23 months)                                                  0.000000
# Life expectancy at birth, total (years)                                                                  0.000000
# Hospital beds (per 1,000 people)                                                                         4.971989
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                             0.023343
# Mortality rate, adult, female (per 1,000 female adults)                                                  0.000000
# Mortality rate, adult, male (per 1,000 male adults)                                                      0.000000
# Mortality caused by road traffic injury (per 100,000 population)                                         0.023343
# Mortality rate, under-5 (per 1,000 live births)                                                          0.000000
# Physicians (per 1,000 people)                                                                            0.023343
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                   0.000000
# Population, total                                                                                        0.000000
# Poverty headcount ratio at societal poverty line (% of population)                                      24.603175
# Prevalence of current tobacco use (% of adults)                                                          9.056956
# Prevalence of undernourishment (% of population)                                                         5.532213
# People using safely managed sanitation services (% of population)                                       22.455649
# Suicide mortality rate (per 100,000 population)                                                          0.023343
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                      1.190476
# dtype: float64

# %%
final_df = final_df.loc[:,nan_colcounts < 10].copy()
final_df
# Out:
#       Country Name  Year  \
# 11485  Afghanistan  2005
# 11744  Afghanistan  2006
# 12002  Afghanistan  2007
# 12260  Afghanistan  2008
# 12518  Afghanistan  2009
# ...            ...   ...
# 14321     Zimbabwe  2015
# 14579     Zimbabwe  2016
# 14837     Zimbabwe  2017
# 15094     Zimbabwe  2018
# 15351     Zimbabwe  2019
#
#        Access to clean fuels and technologies for cooking (% of population)  \
# 11485                                               12.5
# 11744                                               13.9
# 12002                                               15.3
# 12260                                               16.8
# 12518                                               18.2
# ...                                                  ...
# 14321                                               30.0
# 14579                                               30.0
# 14837                                               29.8
# 15094                                               30.0
# 15351                                               30.2
#
#        Access to electricity (% of population)  \
# 11485                                28.669672
# 11744                                33.544418
# 12002                                38.440002
# 12260                                42.400000
# 12518                                48.279007
# ...                                        ...
# 14321                                33.700000
# 14579                                42.465588
# 14837                                43.979065
# 15094                                45.400288
# 15351                                46.682095
#
#        Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 11485                                           0.026840
# 11744                                           0.023954
# 12002                                           0.021068
# 12260                                           0.018182
# 12518                                           0.015296
# ...                                                  ...
# 14321                                           3.747940
# 14579                                           3.717977
# 14837                                           3.688015
# 15094                                           3.658052
# 15351                                           3.628090
#
#        CO2 emissions (metric tons per capita)  GDP per capita (current US$)  \
# 11485                                0.080361                    254.115274
# 11744                                0.089757                    274.015394
# 12002                                0.109940                    376.318296
# 12260                                0.165573                    382.533804
# 12518                                0.239507                    453.387382
# ...                                       ...                           ...
# 14321                                0.846962                   1410.329173
# 14579                                0.723062                   1421.787791
# 14837                                0.663069                   1192.107012
# 15094                                0.735435                   2269.177012
# 15351                                0.663338                   1421.868596
#
#        GNI (current US$)  Current health expenditure per capita (current US$)  \
# 11485       1.010720e+10                                          25.107073
# 11744       1.010720e+10                                          28.919823
# 12002       1.010720e+10                                          32.717205
# 12260       1.010720e+10                                          39.969898
# 12518       1.237834e+10                                          43.260769
# ...                  ...                                                ...
# 14321       1.760488e+10                                         105.098030
# 14579       1.800259e+10                                         106.189697
# 14837       1.559375e+10                                          92.254311
# 15094       3.344290e+10                                         114.633598
# 15351       2.144526e+10                                          54.808506
#
#        Immunization, DPT (% of children ages 12-23 months)  ...  \
# 11485                                               58.0    ...
# 11744                                               58.0    ...
# 12002                                               63.0    ...
# 12260                                               64.0    ...
# 12518                                               63.0    ...
# ...                                                  ...    ...
# 14321                                               87.0    ...
# 14579                                               90.0    ...
# 14837                                               89.0    ...
# 15094                                               89.0    ...
# 15351                                               90.0    ...
#
#        Mortality rate, adult, male (per 1,000 male adults)  \
# 11485                                            310.940
# 11744                                            314.837
# 12002                                            318.012
# 12260                                            305.060
# 12518                                            293.605
# ...                                                  ...
# 14321                                            419.827
# 14579                                            409.210
# 14837                                            405.925
# 15094                                            391.373
# 15351                                            400.483
#
#        Mortality caused by road traffic injury (per 100,000 population)  \
# 11485                                               15.2
# 11744                                               15.1
# 12002                                               15.0
# 12260                                               15.0
# 12518                                               14.4
# ...                                                  ...
# 14321                                               38.7
# 14579                                               39.9
# 14837                                               40.1
# 15094                                               40.6
# 15351                                               41.2
#
#        Mortality rate, under-5 (per 1,000 live births)  \
# 11485                                            108.6
# 11744                                            104.3
# 12002                                            100.0
# 12260                                             95.9
# 12518                                             91.8
# ...                                                ...
# 14321                                             60.5
# 14579                                             57.9
# 14837                                             56.2
# 15094                                             53.7
# 15351                                             52.7
#
#        Physicians (per 1,000 people)  \
# 11485                          0.166
# 11744                          0.166
# 12002                          0.182
# 12260                          0.183
# 12518                          0.220
# ...                              ...
# 14321                          0.177
# 14579                          0.174
# 14837                          0.179
# 15094                          0.201
# 15351                          0.201
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 11485                                          46.151929
# 11744                                          47.285901
# 12002                                          48.419873
# 12260                                          49.553845
# 12518                                          50.687817
# ...                                                  ...
# 14321                                          25.928957
# 14579                                          25.327395
# 14837                                          22.582451
# 15094                                          22.085555
# 15351                                          20.834700
#
#        Population, total  Prevalence of current tobacco use (% of adults)  \
# 11485         24411191.0                                            32.70
# 11744         25442944.0                                            31.98
# 12002         25903301.0                                            31.26
# 12260         26427199.0                                            30.54
# 12518         27385307.0                                            29.82
# ...                  ...                                              ...
# 14321         14154937.0                                            13.60
# 14579         14452704.0                                            13.10
# 14837         14751101.0                                            12.60
# 15094         15052184.0                                            12.10
# 15351         15354608.0                                            12.10
#
#        Prevalence of undernourishment (% of population)  \
# 11485                                              34.5
# 11744                                              31.9
# 12002                                              28.6
# 12260                                              25.4
# 12518                                              22.2
# ...                                                 ...
# 14321                                              32.6
# 14579                                              35.1
# 14837                                              36.3
# 15094                                              38.2
# 15351                                              38.9
#
#        Suicide mortality rate (per 100,000 population)  \
# 11485                                              5.0
# 11744                                              4.9
# 12002                                              4.8
# 12260                                              4.6
# 12518                                              4.4
# ...                                                ...
# 14321                                             18.0
# 14579                                             16.8
# 14837                                             15.0
# 15094                                             14.0
# 15351                                             14.1
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)
# 11485                                              7.925
# 11744                                              7.925
# 12002                                              7.924
# 12260                                              7.928
# 12518                                              7.923
# ...                                                  ...
# 14321                                              5.412
# 14579                                              5.918
# 14837                                              6.349
# 15094                                              6.767
# 15351                                              7.370
#
# [4284 rows x 26 columns]

# %%
print(final_df.isna().any(axis=1).sum())
# Out:
# 936

# %%
final_df.dropna(inplace=True)
final_df.reset_index(drop=True, inplace=True)
final_df
# Out:
#      Country Name  Year  \
# 0     Afghanistan  2005
# 1     Afghanistan  2006
# 2     Afghanistan  2007
# 3     Afghanistan  2008
# 4     Afghanistan  2009
# ...           ...   ...
# 3343     Zimbabwe  2015
# 3344     Zimbabwe  2016
# 3345     Zimbabwe  2017
# 3346     Zimbabwe  2018
# 3347     Zimbabwe  2019
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                  12.5
# 1                                                  13.9
# 2                                                  15.3
# 3                                                  16.8
# 4                                                  18.2
# ...                                                 ...
# 3343                                               30.0
# 3344                                               30.0
# 3345                                               29.8
# 3346                                               30.0
# 3347                                               30.2
#
#       Access to electricity (% of population)  \
# 0                                   28.669672
# 1                                   33.544418
# 2                                   38.440002
# 3                                   42.400000
# 4                                   48.279007
# ...                                       ...
# 3343                                33.700000
# 3344                                42.465588
# 3345                                43.979065
# 3346                                45.400288
# 3347                                46.682095
#
#       Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                              0.026840
# 1                                              0.023954
# 2                                              0.021068
# 3                                              0.018182
# 4                                              0.015296
# ...                                                 ...
# 3343                                           3.747940
# 3344                                           3.717977
# 3345                                           3.688015
# 3346                                           3.658052
# 3347                                           3.628090
#
#       CO2 emissions (metric tons per capita)  GDP per capita (current US$)  \
# 0                                   0.080361                    254.115274
# 1                                   0.089757                    274.015394
# 2                                   0.109940                    376.318296
# 3                                   0.165573                    382.533804
# 4                                   0.239507                    453.387382
# ...                                      ...                           ...
# 3343                                0.846962                   1410.329173
# 3344                                0.723062                   1421.787791
# 3345                                0.663069                   1192.107012
# 3346                                0.735435                   2269.177012
# 3347                                0.663338                   1421.868596
#
#       GNI (current US$)  Current health expenditure per capita (current US$)  \
# 0          1.010720e+10                                          25.107073
# 1          1.010720e+10                                          28.919823
# 2          1.010720e+10                                          32.717205
# 3          1.010720e+10                                          39.969898
# 4          1.237834e+10                                          43.260769
# ...                 ...                                                ...
# 3343       1.760488e+10                                         105.098030
# 3344       1.800259e+10                                         106.189697
# 3345       1.559375e+10                                          92.254311
# 3346       3.344290e+10                                         114.633598
# 3347       2.144526e+10                                          54.808506
#
#       Immunization, DPT (% of children ages 12-23 months)  ...  \
# 0                                                  58.0    ...
# 1                                                  58.0    ...
# 2                                                  63.0    ...
# 3                                                  64.0    ...
# 4                                                  63.0    ...
# ...                                                 ...    ...
# 3343                                               87.0    ...
# 3344                                               90.0    ...
# 3345                                               89.0    ...
# 3346                                               89.0    ...
# 3347                                               90.0    ...
#
#       Mortality rate, adult, male (per 1,000 male adults)  \
# 0                                               310.940
# 1                                               314.837
# 2                                               318.012
# 3                                               305.060
# 4                                               293.605
# ...                                                 ...
# 3343                                            419.827
# 3344                                            409.210
# 3345                                            405.925
# 3346                                            391.373
# 3347                                            400.483
#
#       Mortality caused by road traffic injury (per 100,000 population)  \
# 0                                                  15.2
# 1                                                  15.1
# 2                                                  15.0
# 3                                                  15.0
# 4                                                  14.4
# ...                                                 ...
# 3343                                               38.7
# 3344                                               39.9
# 3345                                               40.1
# 3346                                               40.6
# 3347                                               41.2
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 0                                               108.6
# 1                                               104.3
# 2                                               100.0
# 3                                                95.9
# 4                                                91.8
# ...                                               ...
# 3343                                             60.5
# 3344                                             57.9
# 3345                                             56.2
# 3346                                             53.7
# 3347                                             52.7
#
#       Physicians (per 1,000 people)  \
# 0                             0.166
# 1                             0.166
# 2                             0.182
# 3                             0.183
# 4                             0.220
# ...                             ...
# 3343                          0.177
# 3344                          0.174
# 3345                          0.179
# 3346                          0.201
# 3347                          0.201
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                             46.151929
# 1                                             47.285901
# 2                                             48.419873
# 3                                             49.553845
# 4                                             50.687817
# ...                                                 ...
# 3343                                          25.928957
# 3344                                          25.327395
# 3345                                          22.582451
# 3346                                          22.085555
# 3347                                          20.834700
#
#       Population, total  Prevalence of current tobacco use (% of adults)  \
# 0            24411191.0                                            32.70
# 1            25442944.0                                            31.98
# 2            25903301.0                                            31.26
# 3            26427199.0                                            30.54
# 4            27385307.0                                            29.82
# ...                 ...                                              ...
# 3343         14154937.0                                            13.60
# 3344         14452704.0                                            13.10
# 3345         14751101.0                                            12.60
# 3346         15052184.0                                            12.10
# 3347         15354608.0                                            12.10
#
#       Prevalence of undernourishment (% of population)  \
# 0                                                 34.5
# 1                                                 31.9
# 2                                                 28.6
# 3                                                 25.4
# 4                                                 22.2
# ...                                                ...
# 3343                                              32.6
# 3344                                              35.1
# 3345                                              36.3
# 3346                                              38.2
# 3347                                              38.9
#
#       Suicide mortality rate (per 100,000 population)  \
# 0                                                 5.0
# 1                                                 4.9
# 2                                                 4.8
# 3                                                 4.6
# 4                                                 4.4
# ...                                               ...
# 3343                                             18.0
# 3344                                             16.8
# 3345                                             15.0
# 3346                                             14.0
# 3347                                             14.1
#
#       Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                 7.925
# 1                                                 7.925
# 2                                                 7.924
# 3                                                 7.928
# 4                                                 7.923
# ...                                                 ...
# 3343                                              5.412
# 3344                                              5.918
# 3345                                              6.349
# 3346                                              6.767
# 3347                                              7.370
#
# [3348 rows x 26 columns]

# %%
nan_colcounts = final_df.isna().sum()/final_df.shape[0] * 100
print(nan_colcounts)
# Out:
# Country Name                                                                                            0.0
# Year                                                                                                    0.0
# Access to clean fuels and technologies for cooking (% of population)                                    0.0
# Access to electricity (% of population)                                                                 0.0
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)    0.0
# CO2 emissions (metric tons per capita)                                                                  0.0
# GDP per capita (current US$)                                                                            0.0
# GNI (current US$)                                                                                       0.0
# Current health expenditure per capita (current US$)                                                     0.0
# Immunization, DPT (% of children ages 12-23 months)                                                     0.0
# Immunization, HepB3 (% of one-year-old children)                                                        0.0
# Immunization, measles (% of children ages 12-23 months)                                                 0.0
# Life expectancy at birth, total (years)                                                                 0.0
# Hospital beds (per 1,000 people)                                                                        0.0
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                            0.0
# Mortality rate, adult, female (per 1,000 female adults)                                                 0.0
# Mortality rate, adult, male (per 1,000 male adults)                                                     0.0
# Mortality caused by road traffic injury (per 100,000 population)                                        0.0
# Mortality rate, under-5 (per 1,000 live births)                                                         0.0
# Physicians (per 1,000 people)                                                                           0.0
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                  0.0
# Population, total                                                                                       0.0
# Prevalence of current tobacco use (% of adults)                                                         0.0
# Prevalence of undernourishment (% of population)                                                        0.0
# Suicide mortality rate (per 100,000 population)                                                         0.0
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                     0.0
# dtype: float64

# %%
final_df.to_csv('Datasets/World Bank Cleaned/Life Expectancy World Bank.csv', index=False)
