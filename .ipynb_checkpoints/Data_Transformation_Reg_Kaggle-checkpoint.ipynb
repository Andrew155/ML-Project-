# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', None)
filepath = 'Datasets/World Bank Cleaned/Life Expectancy World Bank.csv'
df = pd.read_csv(filepath)
df.head()
# Out:
#   Country Name  Year  \
# 0  Afghanistan  2005
# 1  Afghanistan  2006
# 2  Afghanistan  2007
# 3  Afghanistan  2008
# 4  Afghanistan  2009
#
#    Access to clean fuels and technologies for cooking (% of population)  \
# 0                                             12.500
# 1                                             13.900
# 2                                             15.300
# 3                                             16.800
# 4                                             18.200
#
#    Access to electricity (% of population)  \
# 0                                   28.670
# 1                                   33.544
# 2                                   38.440
# 3                                   42.400
# 4                                   48.279
#
#    Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                              0.027
# 1                                              0.024
# 2                                              0.021
# 3                                              0.018
# 4                                              0.015
#
#    CO2 emissions (metric tons per capita)  GDP (current US$)  \
# 0                                   0.080     6203256497.090
# 1                                   0.090     6971758332.889
# 2                                   0.110     9747886104.533
# 3                                   0.166    10109296957.657
# 4                                   0.240    12416152648.057
#
#    GNI (current US$)  Current health expenditure per capita (current US$)  \
# 0    10107195903.417                                             25.107
# 1    10107195903.417                                             28.920
# 2    10107195903.417                                             32.717
# 3    10107195903.417                                             39.970
# 4    12378340846.019                                             43.261
#
#    Immunization, DPT (% of children ages 12-23 months)  \
# 0                                             58.000
# 1                                             58.000
# 2                                             63.000
# 3                                             64.000
# 4                                             63.000
#
#    Immunization, HepB3 (% of one-year-old children)  \
# 0                                            63.000
# 1                                            63.000
# 2                                            63.000
# 3                                            64.000
# 4                                            63.000
#
#    Immunization, measles (% of children ages 12-23 months)  \
# 0                                             50.000
# 1                                             53.000
# 2                                             55.000
# 3                                             59.000
# 4                                             60.000
#
#    Life expectancy at birth, total (years)  Hospital beds (per 1,000 people)  \
# 0                                   58.361                             0.420
# 1                                   58.684                             0.420
# 2                                   59.111                             0.420
# 3                                   59.852                             0.420
# 4                                   60.364                             0.420
#
#    Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)  \
# 0                                             40.900
# 1                                             40.500
# 2                                             40.100
# 3                                             39.400
# 4                                             38.400
#
#    Mortality rate, adult, female (per 1,000 female adults)  \
# 0                                            259.868
# 1                                            254.511
# 2                                            247.960
# 3                                            241.256
# 4                                            236.917
#
#    Mortality rate, adult, male (per 1,000 male adults)  \
# 0                                            310.940
# 1                                            314.837
# 2                                            318.012
# 3                                            305.060
# 4                                            293.605
#
#    Mortality caused by road traffic injury (per 100,000 population)  \
# 0                                             15.200
# 1                                             15.100
# 2                                             15.000
# 3                                             15.000
# 4                                             14.400
#
#    Mortality rate, under-5 (per 1,000 live births)  \
# 0                                          108.600
# 1                                          104.300
# 2                                          100.000
# 3                                           95.900
# 4                                           91.800
#
#    Physicians (per 1,000 people)  \
# 0                          0.166
# 1                          0.166
# 2                          0.182
# 3                          0.183
# 4                          0.220
#
#    PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                             46.152
# 1                                             47.286
# 2                                             48.420
# 3                                             49.554
# 4                                             50.688
#
#    Population, total  Prevalence of undernourishment (% of population)  \
# 0       24411191.000                                            34.500
# 1       25442944.000                                            31.900
# 2       25903301.000                                            28.600
# 3       26427199.000                                            25.400
# 4       27385307.000                                            22.200
#
#    Suicide mortality rate (per 100,000 population)  \
# 0                                            5.000
# 1                                            4.900
# 2                                            4.800
# 3                                            4.600
# 4                                            4.400
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                              7.925
# 1                                              7.925
# 2                                              7.924
# 3                                              7.928
# 4                                              7.923

# %%
df.describe()
# Out:
#           Year  \
# count 2930.000
# mean  2009.754
# std      5.727
# min   2000.000
# 25%   2005.000
# 50%   2010.000
# 75%   2015.000
# max   2019.000
#
#        Access to clean fuels and technologies for cooking (% of population)  \
# count                                           2930.000
# mean                                              62.711
# std                                               38.763
# min                                                0.100
# 25%                                               23.350
# 50%                                               80.700
# 75%                                              100.000
# max                                              100.000
#
#        Access to electricity (% of population)  \
# count                                 2930.000
# mean                                    77.945
# std                                     30.448
# min                                      1.280
# 25%                                     56.933
# 50%                                     97.246
# 75%                                    100.000
# max                                    100.000
#
#        Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# count                                           2930.000
# mean                                               5.728
# std                                                4.198
# min                                                0.000
# 25%                                                2.116
# 50%                                                5.322
# 75%                                                8.900
# max                                               19.047
#
#        CO2 emissions (metric tons per capita)  GDP (current US$)  \
# count                                2930.000           2930.000
# mean                                    4.054   411566957339.395
# std                                     4.878  1556169929306.132
# min                                     0.025       75951133.378
# 25%                                     0.599     8752235301.353
# 50%                                     2.192    32682471928.499
# 75%                                     5.990   210792779003.145
# max                                    31.274 21380976119000.000
#
#        GNI (current US$)  Current health expenditure per capita (current US$)  \
# count           2930.000                                           2930.000
# mean    412099840672.237                                            848.426
# std    1574032136913.362                                           1595.854
# min         72802110.899                                              4.448
# 25%       8546227897.176                                             57.190
# 50%      31584287653.180                                            190.400
# 75%     205387340539.192                                            695.165
# max   21760847000000.000                                          10661.028
#
#        Immunization, DPT (% of children ages 12-23 months)  \
# count                                           2930.000
# mean                                              87.144
# std                                               13.924
# min                                               19.000
# 25%                                               83.000
# 50%                                               92.000
# 75%                                               97.000
# max                                               99.000
#
#        Immunization, HepB3 (% of one-year-old children)  \
# count                                          2930.000
# mean                                             82.384
# std                                              20.018
# min                                               2.000
# 25%                                              76.000
# 50%                                              90.500
# 75%                                              96.000
# max                                              99.000
#
#        Immunization, measles (% of children ages 12-23 months)  \
# count                                           2930.000
# mean                                              86.095
# std                                               14.250
# min                                               16.000
# 25%                                               80.000
# 50%                                               92.000
# 75%                                               96.000
# max                                               99.000
#
#        Life expectancy at birth, total (years)  \
# count                                 2930.000
# mean                                    69.608
# std                                      8.909
# min                                     41.957
# 25%                                     63.852
# 50%                                     71.409
# 75%                                     76.449
# max                                     84.356
#
#        Hospital beds (per 1,000 people)  \
# count                          2930.000
# mean                              2.941
# std                               2.517
# min                               0.100
# 25%                               1.000
# 50%                               2.100
# 75%                               4.207
# max                              14.690
#
#        Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)  \
# count                                           2930.000
# mean                                              21.698
# std                                                7.851
# min                                                7.300
# 25%                                               15.725
# 50%                                               21.600
# 75%                                               26.400
# max                                               48.100
#
#        Mortality rate, adult, female (per 1,000 female adults)  \
# count                                           2930.000
# mean                                             153.033
# std                                              114.453
# min                                               22.070
# 25%                                               71.767
# 50%                                              116.269
# 75%                                              200.080
# max                                              752.858
#
#        Mortality rate, adult, male (per 1,000 male adults)  \
# count                                           2930.000
# mean                                             228.582
# std                                              120.767
# min                                               49.162
# 25%                                              137.290
# 50%                                              209.547
# 75%                                              295.014
# max                                              774.859
#
#        Mortality caused by road traffic injury (per 100,000 population)  \
# count                                           2930.000
# mean                                              18.528
# std                                                8.830
# min                                                2.100
# 25%                                               12.100
# 50%                                               17.100
# 75%                                               25.500
# max                                               64.600
#
#        Mortality rate, under-5 (per 1,000 live births)  \
# count                                         2930.000
# mean                                            39.584
# std                                             40.629
# min                                              2.300
# 25%                                              8.625
# 50%                                             22.800
# 75%                                             60.375
# max                                            228.500
#
#        Physicians (per 1,000 people)  \
# count                       2930.000
# mean                           1.605
# std                            1.478
# min                            0.011
# 25%                            0.267
# 50%                            1.248
# 75%                            2.652
# max                            8.427
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# count                                           2930.000
# mean                                              29.216
# std                                               16.905
# min                                                5.447
# 25%                                               17.123
# 50%                                               24.211
# 75%                                               37.459
# max                                               95.243
#
#        Population, total  Prevalence of undernourishment (% of population)  \
# count           2930.000                                          2930.000
# mean        45792805.888                                            11.242
# std        153277176.506                                            10.594
# min           104924.000                                             2.500
# 25%          3537437.250                                             2.500
# 50%         10704332.000                                             6.700
# 75%         32797970.750                                            16.500
# max       1407745000.000                                            54.000
#
#        Suicide mortality rate (per 100,000 population)  \
# count                                         2930.000
# mean                                            10.874
# std                                              9.233
# min                                              0.000
# 25%                                              5.200
# 50%                                              8.200
# 75%                                             13.500
# max                                             92.600
#
#        Unemployment, total (% of total labor force) (modeled ILO estimate)
# count                                           2930.000
# mean                                               7.992
# std                                                5.907
# min                                                0.116
# 25%                                                3.850
# 50%                                                6.215
# 75%                                               10.651
# max                                               37.320

# %%
corr = df.drop(['Country Name', 'Year'], axis=1).corr()
high_corr_pairs = []

# Iterate over the correlation matrix
for i in range(len(corr.columns)):
    for j in range(i + 1, len(corr.columns)):  # i+1 to avoid self-correlation
        if corr.columns[i] == 'Life expectancy at birth, total (years)' or corr.columns[j] == 'Life expectancy at birth, total (years)':
            continue
        if np.abs(corr.iloc[i, j]) > 0.8:  # Check for absolute value > 0.8
            high_corr_pairs.append((corr.columns[i], corr.columns[j], corr.iloc[i, j]))

# Print the pairs
for pair in high_corr_pairs:
    print(f"{pair[0]}, {pair[1]} - Correlation: {pair[2]:.2f}")
# Out:
# Access to clean fuels and technologies for cooking (% of population), Access to electricity (% of population) - Correlation: 0.86
# Access to electricity (% of population), Mortality rate, adult, female (per 1,000 female adults) - Correlation: -0.81
# Access to electricity (% of population), Mortality rate, under-5 (per 1,000 live births) - Correlation: -0.87
# GDP (current US$), GNI (current US$) - Correlation: 1.00
# Immunization, DPT (% of children ages 12-23 months), Immunization, measles (% of children ages 12-23 months) - Correlation: 0.91
# Mortality rate, adult, female (per 1,000 female adults), Mortality rate, adult, male (per 1,000 male adults) - Correlation: 0.93
# Mortality rate, adult, female (per 1,000 female adults), Mortality rate, under-5 (per 1,000 live births) - Correlation: 0.82

# %%
df.drop(['Access to electricity (% of population)', 'GNI (current US$)', 'Immunization, DPT (% of children ages 12-23 months)',
        'Mortality rate, adult, female (per 1,000 female adults)'], axis=1, inplace=True)
df
# Out:
#      Country Name  Year  \
# 0     Afghanistan  2005
# 1     Afghanistan  2006
# 2     Afghanistan  2007
# 3     Afghanistan  2008
# 4     Afghanistan  2009
# ...           ...   ...
# 2925     Zimbabwe  2015
# 2926     Zimbabwe  2016
# 2927     Zimbabwe  2017
# 2928     Zimbabwe  2018
# 2929     Zimbabwe  2019
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                12.500
# 1                                                13.900
# 2                                                15.300
# 3                                                16.800
# 4                                                18.200
# ...                                                 ...
# 2925                                             30.000
# 2926                                             30.000
# 2927                                             29.800
# 2928                                             30.000
# 2929                                             30.200
#
#       Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                                 0.027
# 1                                                 0.024
# 2                                                 0.021
# 3                                                 0.018
# 4                                                 0.015
# ...                                                 ...
# 2925                                              3.748
# 2926                                              3.718
# 2927                                              3.688
# 2928                                              3.658
# 2929                                              3.628
#
#       CO2 emissions (metric tons per capita)  GDP (current US$)  \
# 0                                      0.080     6203256497.090
# 1                                      0.090     6971758332.889
# 2                                      0.110     9747886104.533
# 3                                      0.166    10109296957.657
# 4                                      0.240    12416152648.057
# ...                                      ...                ...
# 2925                                   0.847    19963120600.000
# 2926                                   0.723    20548678100.000
# 2927                                   0.663    17584890936.652
# 2928                                   0.735    34156069918.061
# 2929                                   0.663    21832234921.176
#
#       Current health expenditure per capita (current US$)  \
# 0                                                25.107
# 1                                                28.920
# 2                                                32.717
# 3                                                39.970
# 4                                                43.261
# ...                                                 ...
# 2925                                            105.098
# 2926                                            106.190
# 2927                                             92.254
# 2928                                            114.634
# 2929                                             54.809
#
#       Immunization, HepB3 (% of one-year-old children)  \
# 0                                               63.000
# 1                                               63.000
# 2                                               63.000
# 3                                               64.000
# 4                                               63.000
# ...                                                ...
# 2925                                            87.000
# 2926                                            90.000
# 2927                                            89.000
# 2928                                            89.000
# 2929                                            90.000
#
#       Immunization, measles (% of children ages 12-23 months)  \
# 0                                                50.000
# 1                                                53.000
# 2                                                55.000
# 3                                                59.000
# 4                                                60.000
# ...                                                 ...
# 2925                                             86.000
# 2926                                             95.000
# 2927                                             90.000
# 2928                                             88.000
# 2929                                             85.000
#
#       Life expectancy at birth, total (years)  \
# 0                                      58.361
# 1                                      58.684
# 2                                      59.111
# 3                                      59.852
# 4                                      60.364
# ...                                       ...
# 2925                                   59.591
# 2926                                   60.306
# 2927                                   60.709
# 2928                                   61.414
# 2929                                   61.292
#
#       Hospital beds (per 1,000 people)  \
# 0                                0.420
# 1                                0.420
# 2                                0.420
# 3                                0.420
# 4                                0.420
# ...                                ...
# 2925                             1.700
# 2926                             1.700
# 2927                             1.700
# 2928                             1.700
# 2929                             1.700
#
#       Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)  \
# 0                                                40.900
# 1                                                40.500
# 2                                                40.100
# 3                                                39.400
# 4                                                38.400
# ...                                                 ...
# 2925                                             31.100
# 2926                                             30.400
# 2927                                             29.300
# 2928                                             28.500
# 2929                                             28.400
#
#       Mortality rate, adult, male (per 1,000 male adults)  \
# 0                                               310.940
# 1                                               314.837
# 2                                               318.012
# 3                                               305.060
# 4                                               293.605
# ...                                                 ...
# 2925                                            419.827
# 2926                                            409.210
# 2927                                            405.925
# 2928                                            391.373
# 2929                                            400.483
#
#       Mortality caused by road traffic injury (per 100,000 population)  \
# 0                                                15.200
# 1                                                15.100
# 2                                                15.000
# 3                                                15.000
# 4                                                14.400
# ...                                                 ...
# 2925                                             38.700
# 2926                                             39.900
# 2927                                             40.100
# 2928                                             40.600
# 2929                                             41.200
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 0                                             108.600
# 1                                             104.300
# 2                                             100.000
# 3                                              95.900
# 4                                              91.800
# ...                                               ...
# 2925                                           60.500
# 2926                                           57.900
# 2927                                           56.200
# 2928                                           53.700
# 2929                                           52.700
#
#       Physicians (per 1,000 people)  \
# 0                             0.166
# 1                             0.166
# 2                             0.182
# 3                             0.183
# 4                             0.220
# ...                             ...
# 2925                          0.177
# 2926                          0.174
# 2927                          0.179
# 2928                          0.201
# 2929                          0.201
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                46.152
# 1                                                47.286
# 2                                                48.420
# 3                                                49.554
# 4                                                50.688
# ...                                                 ...
# 2925                                             25.929
# 2926                                             25.327
# 2927                                             22.582
# 2928                                             22.086
# 2929                                             20.835
#
#       Population, total  Prevalence of undernourishment (% of population)  \
# 0          24411191.000                                            34.500
# 1          25442944.000                                            31.900
# 2          25903301.000                                            28.600
# 3          26427199.000                                            25.400
# 4          27385307.000                                            22.200
# ...                 ...                                               ...
# 2925       14154937.000                                            32.600
# 2926       14452704.000                                            35.100
# 2927       14751101.000                                            36.300
# 2928       15052184.000                                            38.200
# 2929       15354608.000                                            38.900
#
#       Suicide mortality rate (per 100,000 population)  \
# 0                                               5.000
# 1                                               4.900
# 2                                               4.800
# 3                                               4.600
# 4                                               4.400
# ...                                               ...
# 2925                                           18.000
# 2926                                           16.800
# 2927                                           15.000
# 2928                                           14.000
# 2929                                           14.100
#
#       Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                 7.925
# 1                                                 7.925
# 2                                                 7.924
# 3                                                 7.928
# 4                                                 7.923
# ...                                                 ...
# 2925                                              5.412
# 2926                                              5.918
# 2927                                              6.349
# 2928                                              6.767
# 2929                                              7.370
#
# [2930 rows x 21 columns]

# %%
df.skew(axis = 0, numeric_only = True)
# Out:
# Year                                                                                                   -0.062
# Access to clean fuels and technologies for cooking (% of population)                                   -0.484
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)    0.447
# CO2 emissions (metric tons per capita)                                                                  2.030
# GDP (current US$)                                                                                       8.228
# Current health expenditure per capita (current US$)                                                     2.869
# Immunization, HepB3 (% of one-year-old children)                                                       -1.839
# Immunization, measles (% of children ages 12-23 months)                                                -1.591
# Life expectancy at birth, total (years)                                                                -0.694
# Hospital beds (per 1,000 people)                                                                        1.451
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                            0.514
# Mortality rate, adult, male (per 1,000 male adults)                                                     1.228
# Mortality caused by road traffic injury (per 100,000 population)                                        0.304
# Mortality rate, under-5 (per 1,000 live births)                                                         1.452
# Physicians (per 1,000 people)                                                                           0.918
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                  1.077
# Population, total                                                                                       7.362
# Prevalence of undernourishment (% of population)                                                        1.364
# Suicide mortality rate (per 100,000 population)                                                         2.885
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                     1.490
# dtype: float64

# %%
def plot_histogram(data, ylabel, xlabel, title):
    plt.figure(figsize = (10, 6))
    plt.hist(data, edgecolor="white")
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title);
def get_outlier(df, column):
    Q1 = np.percentile(df[column], 25, method='midpoint')
    Q3 = np.percentile(df[column], 75, method='midpoint')
    IQR = Q3 - Q1
    return df[(df[column]>=(Q3+1.5*IQR)) | (df[column]<=(Q1-1.5*IQR))].sort_values(by=[column]).reset_index()

# %%
plot_histogram(df['GDP (current US$)'], 'Count', 'GDP (current US$)', 'Histogram of GDP')

# %%
sns.boxplot(data=df, x=df['GDP (current US$)'])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='GDP (current US$)'>

# %%
outlier = get_outlier(df, 'GDP (current US$)')[['Country Name', 'Year', 'GDP (current US$)']]
outlier
# Out:
#       Country Name  Year  GDP (current US$)
# 0            India  2002   514937948874.212
# 1           Sweden  2016   515654671469.547
# 2           Poland  2013   515761954074.157
# 3          Belgium  2008   517328087920.078
# 4           Sweden  2008   517706149201.196
# ..             ...   ...                ...
# 385  United States  2015 18206020741000.000
# 386  United States  2016 18695110842000.000
# 387  United States  2017 19477336549000.000
# 388  United States  2018 20533057312000.000
# 389  United States  2019 21380976119000.000
#
# [390 rows x 3 columns]

# %%
df['GDP (current US$)'] = np.log(df['GDP (current US$)'])
df.rename(columns={'GDP (current US$)': 'GDP (current US$)_log'}, inplace=True)
sns.boxplot(data=df, x=df['GDP (current US$)_log'])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='GDP (current US$)_log'>

# %%
plot_histogram(df['Population, total'], 'Count', 'Population, total', 'Histogram of Population')

# %%
outlier = get_outlier(df, 'Population, total')[['Country Name', 'Year', 'Population, total']]
outlier
# Out:
#            Country Name  Year  Population, total
# 0               Turkiye  2014       77181884.000
# 1    Iran, Islamic Rep.  2012       77324451.000
# 2              Ethiopia  2005       77469940.000
# 3      Egypt, Arab Rep.  2004       77522427.000
# 4           Philippines  2000       77958223.000
# ..                  ...   ...                ...
# 323               India  2019     1383112050.000
# 324               China  2016     1387790000.000
# 325               China  2017     1396215000.000
# 326               China  2018     1402760000.000
# 327               China  2019     1407745000.000
#
# [328 rows x 3 columns]

# %%
df['Population, total'] = np.log(df['Population, total'])
df.rename(columns={'Population, total': 'Population, total_log'}, inplace=True)
sns.boxplot(data=df, x=df['Population, total_log'])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Population, total_log'>

# %%
df.skew(axis = 0, numeric_only = True)
# Out:
# Year                                                                                                   -0.062
# Access to clean fuels and technologies for cooking (% of population)                                   -0.484
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)    0.447
# CO2 emissions (metric tons per capita)                                                                  2.030
# GDP (current US$)_log                                                                                   0.167
# Current health expenditure per capita (current US$)                                                     2.869
# Immunization, HepB3 (% of one-year-old children)                                                       -1.839
# Immunization, measles (% of children ages 12-23 months)                                                -1.591
# Life expectancy at birth, total (years)                                                                -0.694
# Hospital beds (per 1,000 people)                                                                        1.451
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)                            0.514
# Mortality rate, adult, male (per 1,000 male adults)                                                     1.228
# Mortality caused by road traffic injury (per 100,000 population)                                        0.304
# Mortality rate, under-5 (per 1,000 live births)                                                         1.452
# Physicians (per 1,000 people)                                                                           0.918
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)                                  1.077
# Population, total_log                                                                                  -0.096
# Prevalence of undernourishment (% of population)                                                        1.364
# Suicide mortality rate (per 100,000 population)                                                         2.885
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                     1.490
# dtype: float64

# %%
X = df.drop(['Country Name', 'Year', 'Life expectancy at birth, total (years)'], axis=1)
y = df.loc[:,'Life expectancy at birth, total (years)']
X
# Out:
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                12.500
# 1                                                13.900
# 2                                                15.300
# 3                                                16.800
# 4                                                18.200
# ...                                                 ...
# 2925                                             30.000
# 2926                                             30.000
# 2927                                             29.800
# 2928                                             30.000
# 2929                                             30.200
#
#       Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                                 0.027
# 1                                                 0.024
# 2                                                 0.021
# 3                                                 0.018
# 4                                                 0.015
# ...                                                 ...
# 2925                                              3.748
# 2926                                              3.718
# 2927                                              3.688
# 2928                                              3.658
# 2929                                              3.628
#
#       CO2 emissions (metric tons per capita)  GDP (current US$)_log  \
# 0                                      0.080                 22.548
# 1                                      0.090                 22.665
# 2                                      0.110                 23.000
# 3                                      0.166                 23.037
# 4                                      0.240                 23.242
# ...                                      ...                    ...
# 2925                                   0.847                 23.717
# 2926                                   0.723                 23.746
# 2927                                   0.663                 23.590
# 2928                                   0.735                 24.254
# 2929                                   0.663                 23.807
#
#       Current health expenditure per capita (current US$)  \
# 0                                                25.107
# 1                                                28.920
# 2                                                32.717
# 3                                                39.970
# 4                                                43.261
# ...                                                 ...
# 2925                                            105.098
# 2926                                            106.190
# 2927                                             92.254
# 2928                                            114.634
# 2929                                             54.809
#
#       Immunization, HepB3 (% of one-year-old children)  \
# 0                                               63.000
# 1                                               63.000
# 2                                               63.000
# 3                                               64.000
# 4                                               63.000
# ...                                                ...
# 2925                                            87.000
# 2926                                            90.000
# 2927                                            89.000
# 2928                                            89.000
# 2929                                            90.000
#
#       Immunization, measles (% of children ages 12-23 months)  \
# 0                                                50.000
# 1                                                53.000
# 2                                                55.000
# 3                                                59.000
# 4                                                60.000
# ...                                                 ...
# 2925                                             86.000
# 2926                                             95.000
# 2927                                             90.000
# 2928                                             88.000
# 2929                                             85.000
#
#       Hospital beds (per 1,000 people)  \
# 0                                0.420
# 1                                0.420
# 2                                0.420
# 3                                0.420
# 4                                0.420
# ...                                ...
# 2925                             1.700
# 2926                             1.700
# 2927                             1.700
# 2928                             1.700
# 2929                             1.700
#
#       Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)  \
# 0                                                40.900
# 1                                                40.500
# 2                                                40.100
# 3                                                39.400
# 4                                                38.400
# ...                                                 ...
# 2925                                             31.100
# 2926                                             30.400
# 2927                                             29.300
# 2928                                             28.500
# 2929                                             28.400
#
#       Mortality rate, adult, male (per 1,000 male adults)  \
# 0                                               310.940
# 1                                               314.837
# 2                                               318.012
# 3                                               305.060
# 4                                               293.605
# ...                                                 ...
# 2925                                            419.827
# 2926                                            409.210
# 2927                                            405.925
# 2928                                            391.373
# 2929                                            400.483
#
#       Mortality caused by road traffic injury (per 100,000 population)  \
# 0                                                15.200
# 1                                                15.100
# 2                                                15.000
# 3                                                15.000
# 4                                                14.400
# ...                                                 ...
# 2925                                             38.700
# 2926                                             39.900
# 2927                                             40.100
# 2928                                             40.600
# 2929                                             41.200
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 0                                             108.600
# 1                                             104.300
# 2                                             100.000
# 3                                              95.900
# 4                                              91.800
# ...                                               ...
# 2925                                           60.500
# 2926                                           57.900
# 2927                                           56.200
# 2928                                           53.700
# 2929                                           52.700
#
#       Physicians (per 1,000 people)  \
# 0                             0.166
# 1                             0.166
# 2                             0.182
# 3                             0.183
# 4                             0.220
# ...                             ...
# 2925                          0.177
# 2926                          0.174
# 2927                          0.179
# 2928                          0.201
# 2929                          0.201
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                46.152
# 1                                                47.286
# 2                                                48.420
# 3                                                49.554
# 4                                                50.688
# ...                                                 ...
# 2925                                             25.929
# 2926                                             25.327
# 2927                                             22.582
# 2928                                             22.086
# 2929                                             20.835
#
#       Population, total_log  Prevalence of undernourishment (% of population)  \
# 0                    17.011                                            34.500
# 1                    17.052                                            31.900
# 2                    17.070                                            28.600
# 3                    17.090                                            25.400
# 4                    17.126                                            22.200
# ...                     ...                                               ...
# 2925                 16.466                                            32.600
# 2926                 16.486                                            35.100
# 2927                 16.507                                            36.300
# 2928                 16.527                                            38.200
# 2929                 16.547                                            38.900
#
#       Suicide mortality rate (per 100,000 population)  \
# 0                                               5.000
# 1                                               4.900
# 2                                               4.800
# 3                                               4.600
# 4                                               4.400
# ...                                               ...
# 2925                                           18.000
# 2926                                           16.800
# 2927                                           15.000
# 2928                                           14.000
# 2929                                           14.100
#
#       Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                 7.925
# 1                                                 7.925
# 2                                                 7.924
# 3                                                 7.928
# 4                                                 7.923
# ...                                                 ...
# 2925                                              5.412
# 2926                                              5.918
# 2927                                              6.349
# 2928                                              6.767
# 2929                                              7.370
#
# [2930 rows x 18 columns]

# %%
y
# Out:
# 0      58.361
# 1      58.684
# 2      59.111
# 3      59.852
# 4      60.364
#         ...
# 2925   59.591
# 2926   60.306
# 2927   60.709
# 2928   61.414
# 2929   61.292
# Name: Life expectancy at birth, total (years), Length: 2930, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train
# Out:
#       Access to clean fuels and technologies for cooking (% of population)  \
# 2073                                             41.300
# 2754                                            100.000
# 1282                                             84.000
# 1572                                             98.100
# 641                                              23.100
# ...                                                 ...
# 763                                              90.000
# 835                                             100.000
# 1653                                             97.700
# 2607                                            100.000
# 2732                                            100.000
#
#       Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 2073                                              6.068
# 2754                                             10.591
# 1282                                              3.096
# 1572                                              0.587
# 641                                               2.569
# ...                                                 ...
# 763                                               6.668
# 835                                              14.434
# 1653                                              7.618
# 2607                                              6.120
# 2732                                              2.285
#
#       CO2 emissions (metric tons per capita)  GDP (current US$)_log  \
# 2073                                   0.857                 26.180
# 2754                                   5.825                 28.620
# 1282                                   4.453                 23.273
# 1572                                   6.441                 25.690
# 641                                    0.416                 24.548
# ...                                      ...                    ...
# 763                                    2.212                 25.105
# 835                                   10.527                 23.700
# 1653                                   2.906                 23.167
# 2607                                  13.581                 23.677
# 2732                                  21.123                 26.749
#
#       Current health expenditure per capita (current US$)  \
# 2073                                             97.860
# 2754                                           4037.808
# 1282                                            252.113
# 1572                                            161.630
# 641                                              62.517
# ...                                                 ...
# 763                                             337.609
# 835                                             963.020
# 1653                                            385.772
# 2607                                            764.354
# 2732                                           1656.269
#
#       Immunization, HepB3 (% of one-year-old children)  \
# 2073                                            89.000
# 2754                                            93.000
# 1282                                            92.000
# 1572                                            96.000
# 641                                             79.000
# ...                                                ...
# 763                                             81.000
# 835                                             95.000
# 1653                                            98.000
# 2607                                            90.000
# 2732                                            99.000
#
#       Immunization, measles (% of children ages 12-23 months)  \
# 2073                                             86.000
# 2754                                             92.000
# 1282                                             76.000
# 1572                                             96.000
# 641                                              67.000
# ...                                                 ...
# 763                                              86.000
# 835                                              95.000
# 1653                                             99.000
# 2607                                             94.000
# 2732                                             99.000
#
#       Hospital beds (per 1,000 people)  \
# 2073                             1.070
# 2754                             2.570
# 1282                             1.700
# 1572                             1.800
# 641                              0.400
# ...                                ...
# 763                              1.560
# 835                              5.370
# 1653                             3.400
# 2607                             2.600
# 2732                             1.125
#
#       Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)  \
# 2073                                             24.200
# 2754                                             11.300
# 1282                                             15.500
# 1572                                             20.400
# 641                                              23.600
# ...                                                 ...
# 763                                              21.000
# 835                                              20.700
# 1653                                             24.100
# 2607                                             21.700
# 2732                                             20.300
#
#       Mortality rate, adult, male (per 1,000 male adults)  \
# 2073                                            167.239
# 2754                                             85.682
# 1282                                            196.577
# 1572                                            168.842
# 641                                             360.727
# ...                                                 ...
# 763                                             190.068
# 835                                             229.240
# 1653                                            192.239
# 2607                                            204.012
# 2732                                             76.298
#
#       Mortality caused by road traffic injury (per 100,000 population)  \
# 2073                                             10.500
# 2754                                              3.000
# 1282                                             12.700
# 1572                                             24.900
# 641                                              23.200
# ...                                                 ...
# 763                                              46.300
# 835                                               8.800
# 1653                                             15.000
# 2607                                             22.100
# 2732                                             17.800
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 2073                                           31.400
# 2754                                            4.400
# 1282                                           18.400
# 1572                                            8.200
# 641                                            90.500
# ...                                               ...
# 763                                            35.100
# 835                                             5.000
# 1653                                           14.800
# 2607                                           23.500
# 2732                                            7.800
#
#       Physicians (per 1,000 people)  \
# 2073                          1.178
# 2754                          2.783
# 1282                          0.496
# 1572                          0.776
# 641                           0.226
# ...                             ...
# 763                           1.409
# 835                           3.280
# 1653                          1.407
# 2607                          1.422
# 2732                          2.081
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 2073                                             20.854
# 2754                                             10.214
# 1282                                             15.178
# 1572                                             20.102
# 641                                              63.411
# ...                                                 ...
# 763                                              17.742
# 835                                               8.592
# 1653                                             15.012
# 2607                                             19.971
# 2732                                             41.096
#
#       Population, total_log  Prevalence of undernourishment (% of population)  \
# 2073                 18.383                                            12.500
# 2754                 17.999                                             2.500
# 1282                 14.809                                             8.800
# 1572                 17.071                                             3.100
# 641                  16.977                                            11.900
# ...                     ...                                               ...
# 763                  16.181                                             6.000
# 835                  14.104                                             2.500
# 1653                 14.041                                             5.100
# 2607                 14.153                                            10.600
# 2732                 15.994                                             4.700
#
#       Suicide mortality rate (per 100,000 population)  \
# 2073                                            2.700
# 2754                                            8.500
# 1282                                            1.800
# 1572                                            4.600
# 641                                            10.000
# ...                                               ...
# 763                                             5.700
# 835                                            23.300
# 1653                                            9.000
# 2607                                           11.200
# 2732                                            7.000
#
#       Unemployment, total (% of total labor force) (modeled ILO estimate)
# 2073                                              3.590
# 2754                                              4.810
# 1282                                              6.619
# 1572                                              3.530
# 641                                               2.537
# ...                                                 ...
# 763                                               5.830
# 835                                              13.550
# 1653                                              7.450
# 2607                                              5.280
# 2732                                              1.956
#
# [2344 rows x 18 columns]

# %%
scaler = StandardScaler()
transformed_X_train = scaler.fit_transform(X_train)
transformed_X_test = scaler.transform(X_test)
pd.DataFrame(transformed_X_train).to_csv('Datasets/World Bank Transformed/X_train without PCA.csv', index=False, header=X_test.columns)
pd.DataFrame(transformed_X_test).to_csv('Datasets/World Bank Transformed/X_test without PCA.csv', index=False, header=X_test.columns)
y_train.to_csv('Datasets/World Bank Transformed/y_train.csv', index=False)
y_test.to_csv('Datasets/World Bank Transformed/y_test.csv', index=False)

# %%
pd.DataFrame(transformed_X_train, columns=X_test.columns)
# Out:
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                -0.559
# 1                                                 0.958
# 2                                                 0.545
# 3                                                 0.909
# 4                                                -1.029
# ...                                                 ...
# 2339                                              0.700
# 2340                                              0.958
# 2341                                              0.899
# 2342                                              0.958
# 2343                                              0.958
#
#       Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                                 0.100
# 1                                                 1.176
# 2                                                -0.607
# 3                                                -1.204
# 4                                                -0.732
# ...                                                 ...
# 2339                                              0.243
# 2340                                              2.090
# 2341                                              0.469
# 2342                                              0.112
# 2343                                             -0.800
#
#       CO2 emissions (metric tons per capita)  GDP (current US$)_log  \
# 0                                     -0.655                  0.793
# 1                                      0.345                  1.896
# 2                                      0.069                 -0.521
# 3                                      0.469                  0.572
# 4                                     -0.744                  0.055
# ...                                      ...                    ...
# 2339                                  -0.383                  0.307
# 2340                                   1.291                 -0.328
# 2341                                  -0.243                 -0.569
# 2342                                   1.906                 -0.338
# 2343                                   3.424                  1.051
#
#       Current health expenditure per capita (current US$)  \
# 0                                                -0.468
# 1                                                 2.029
# 2                                                -0.370
# 3                                                -0.427
# 4                                                -0.490
# ...                                                 ...
# 2339                                             -0.316
# 2340                                              0.080
# 2341                                             -0.285
# 2342                                             -0.045
# 2343                                              0.520
#
#       Immunization, HepB3 (% of one-year-old children)  \
# 0                                                0.325
# 1                                                0.527
# 2                                                0.477
# 3                                                0.679
# 4                                               -0.180
# ...                                                ...
# 2339                                            -0.079
# 2340                                             0.628
# 2341                                             0.780
# 2342                                             0.376
# 2343                                             0.830
#
#       Immunization, measles (% of children ages 12-23 months)  \
# 0                                                -0.006
# 1                                                 0.417
# 2                                                -0.711
# 3                                                 0.699
# 4                                                -1.346
# ...                                                 ...
# 2339                                             -0.006
# 2340                                              0.629
# 2341                                              0.911
# 2342                                              0.558
# 2343                                              0.911
#
#       Hospital beds (per 1,000 people)  \
# 0                               -0.727
# 1                               -0.135
# 2                               -0.478
# 3                               -0.439
# 4                               -0.991
# ...                                ...
# 2339                            -0.534
# 2340                             0.970
# 2341                             0.193
# 2342                            -0.123
# 2343                            -0.705
#
#       Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)  \
# 0                                                 0.309
# 1                                                -1.339
# 2                                                -0.803
# 3                                                -0.177
# 4                                                 0.232
# ...                                                 ...
# 2339                                             -0.100
# 2340                                             -0.138
# 2341                                              0.296
# 2342                                             -0.011
# 2343                                             -0.189
#
#       Mortality rate, adult, male (per 1,000 male adults)  \
# 0                                                -0.511
# 1                                                -1.190
# 2                                                -0.266
# 3                                                -0.497
# 4                                                 1.100
# ...                                                 ...
# 2339                                             -0.320
# 2340                                              0.006
# 2341                                             -0.302
# 2342                                             -0.204
# 2343                                             -1.268
#
#       Mortality caused by road traffic injury (per 100,000 population)  \
# 0                                                -0.920
# 1                                                -1.771
# 2                                                -0.671
# 3                                                 0.713
# 4                                                 0.520
# ...                                                 ...
# 2339                                              3.140
# 2340                                             -1.113
# 2341                                             -0.410
# 2342                                              0.395
# 2343                                             -0.092
#
#       Mortality rate, under-5 (per 1,000 live births)  \
# 0                                              -0.207
# 1                                              -0.865
# 2                                              -0.524
# 3                                              -0.773
# 4                                               1.236
# ...                                               ...
# 2339                                           -0.116
# 2340                                           -0.851
# 2341                                           -0.612
# 2342                                           -0.399
# 2343                                           -0.782
#
#       Physicians (per 1,000 people)  \
# 0                            -0.286
# 1                             0.807
# 2                            -0.750
# 3                            -0.559
# 4                            -0.934
# ...                             ...
# 2339                         -0.128
# 2340                          1.145
# 2341                         -0.130
# 2342                         -0.120
# 2343                          0.329
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                -0.505
# 1                                                -1.130
# 2                                                -0.838
# 3                                                -0.549
# 4                                                 1.993
# ...                                                 ...
# 2339                                             -0.688
# 2340                                             -1.225
# 2341                                             -0.848
# 2342                                             -0.557
# 2343                                              0.683
#
#       Population, total_log  Prevalence of undernourishment (% of population)  \
# 0                     1.298                                             0.120
# 1                     1.072                                            -0.824
# 2                    -0.803                                            -0.229
# 3                     0.527                                            -0.767
# 4                     0.471                                             0.064
# ...                     ...                                               ...
# 2339                  0.003                                            -0.493
# 2340                 -1.218                                            -0.824
# 2341                 -1.255                                            -0.578
# 2342                 -1.189                                            -0.059
# 2343                 -0.106                                            -0.616
#
#       Suicide mortality rate (per 100,000 population)  \
# 0                                              -0.874
# 1                                              -0.252
# 2                                              -0.971
# 3                                              -0.670
# 4                                              -0.091
# ...                                               ...
# 2339                                           -0.552
# 2340                                            1.336
# 2341                                           -0.198
# 2342                                            0.038
# 2343                                           -0.413
#
#       Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                -0.746
# 1                                                -0.541
# 2                                                -0.238
# 3                                                -0.756
# 4                                                -0.922
# ...                                                 ...
# 2339                                             -0.370
# 2340                                              0.924
# 2341                                             -0.099
# 2342                                             -0.462
# 2343                                             -1.020
#
# [2344 rows x 18 columns]

# %%
pca = PCA(n_components=0.9)
pca_data = pca.fit(transformed_X_train)
pca_data.explained_variance_ratio_
# Out:
# array([0.40093816, 0.13106448, 0.08896412, 0.07306554, 0.05330895,
#        0.0448115 , 0.03804824, 0.03018307, 0.02647974, 0.0240343 ])

# %%
np.cumsum(np.round(pca_data.explained_variance_ratio_, decimals = 4) * 100)
# Out:
# array([40.09, 53.2 , 62.1 , 69.41, 74.74, 79.22, 83.02, 86.04, 88.69,
#        91.09])

# %%
X_train = pca.transform(transformed_X_train)
X_test = pca.transform(transformed_X_test)
X_train.shape
# Out:
# (2344, 10)

# %%
header = [f'PCA{i}' for i in range(1,11)]
pd.DataFrame(X_train).to_csv('Datasets/World Bank Transformed/X_train with PCA.csv', index=False, header=header)
pd.DataFrame(X_test).to_csv('Datasets/World Bank Transformed/X_test with PCA.csv', index=False, header=header)
