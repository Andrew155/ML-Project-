# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', None)
filepath = 'Datasets/Kaggle Cleaned/Life Expectancy Kaggle.csv'
df = pd.read_csv(filepath)
df.head()
# Out:
#        Country  Year  Life expectancy  Adult mortality  Infant deaths  \
# 0  Afghanistan  2000           54.800          321.000             88
# 1  Afghanistan  2001           55.300          316.000             88
# 2  Afghanistan  2002           56.200            3.000             88
# 3  Afghanistan  2003           56.700          295.000             87
# 4  Afghanistan  2004           57.000          293.000             87
#
#    Alcohol  Percentage expenditure  Hepatitis B  Measles    BMI  \
# 0    0.010                  10.425       62.000     6532 12.200
# 1    0.010                  10.575       63.000     8762 12.600
# 2    0.010                  16.887       64.000     2486 13.000
# 3    0.010                  11.089       65.000      798 13.400
# 4    0.020                  15.296       67.000      466 13.800
#
#    Under-five deaths  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0                122 24.000              8.200      24.000     0.100
# 1                122 35.000              7.800      33.000     0.100
# 2                122 36.000              7.760      36.000     0.100
# 3                122 41.000              8.820      41.000     0.100
# 4                120  5.000              8.790       5.000     0.100
#
#    Thinness 1-19 years  Thinness 5-9 years  Income composition of resources  \
# 0                2.300               2.500                            0.338
# 1                2.100               2.400                            0.340
# 2               19.900               2.200                            0.341
# 3               19.700              19.900                            0.373
# 4               19.500              19.700                            0.381
#
#    Schooling
# 0      5.500
# 1      5.900
# 2      6.200
# 3      6.500
# 4      6.800

# %%
df.describe()
# Out:
#           Year  Life expectancy  Adult mortality  Infant deaths  Alcohol  \
# count 2445.000         2445.000         2445.000       2445.000 2445.000
# mean  2007.000           68.795          166.645         31.063    4.310
# std      4.321            9.260          125.083        125.768    3.938
# min   2000.000           36.300            1.000          0.000    0.010
# 25%   2003.000           63.000           76.000          0.000    0.680
# 50%   2007.000           71.800          146.000          3.000    3.410
# 75%   2011.000           75.000          227.000         20.000    7.170
# max   2014.000           89.000          723.000       1800.000   17.870
#
#        Percentage expenditure  Hepatitis B    Measles      BMI  \
# count                2445.000     2445.000   2445.000 2445.000
# mean                  666.402       75.976   2309.798   37.670
# std                  1683.994       28.413  10974.311   19.778
# min                     0.000        2.000      0.000    1.000
# 25%                    16.755       67.000      0.000   18.800
# 50%                    90.761       89.000     16.000   42.700
# 75%                   471.831       96.000    353.000   55.500
# max                 18961.349       99.000 212183.000   77.100
#
#        Under-five deaths    Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# count           2445.000 2445.000           2445.000    2445.000  2445.000
# mean              43.022   82.087              5.769      81.998     1.917
# std              171.249   23.470              2.307      23.703     5.482
# min                0.000    3.000              0.370       2.000     0.100
# 25%                0.000   77.000              4.240      78.000     0.100
# 50%                4.000   92.000              5.620      92.000     0.100
# 75%               25.000   97.000              7.200      97.000     0.900
# max             2500.000   99.000             14.390      99.000    50.600
#
#        Thinness 1-19 years  Thinness 5-9 years  \
# count             2445.000            2445.000
# mean                 5.084               5.129
# std                  4.531               4.621
# min                  0.100               0.100
# 25%                  1.700               1.700
# 50%                  3.500               3.500
# 75%                  7.400               7.400
# max                 27.700              28.600
#
#        Income composition of resources  Schooling
# count                         2445.000   2445.000
# mean                             0.615     11.815
# std                              0.207      3.162
# min                              0.000      0.000
# 25%                              0.487     10.000
# 50%                              0.666     12.200
# 75%                              0.760     13.900
# max                              0.936     20.700

# %%
corr = df.drop(['Country', 'Year',], axis=1).corr()
high_corr_pairs = []

# Iterate over the correlation matrix
for i in range(len(corr.columns)):
    for j in range(i + 1, len(corr.columns)):  # i+1 to avoid self-correlation
        if corr.columns[i] == 'Life expectancy' or corr.columns[j] == 'Life expectancy':
            continue
        if np.abs(corr.iloc[i, j]) > 0.8:  # Check for absolute value > 0.8
            high_corr_pairs.append((corr.columns[i], corr.columns[j], corr.iloc[i, j]))

# Print the pairs
for pair in high_corr_pairs:
    print(f"{pair[0]}, {pair[1]} - Correlation: {pair[2]:.2f}")
# Out:
# Infant deaths, Under-five deaths - Correlation: 1.00
# Thinness 1-19 years, Thinness 5-9 years - Correlation: 0.93

# %%
df.drop(['Thinness 5-9 years', 'Under-five deaths'], axis=1, inplace=True)
df
# Out:
#           Country  Year  Life expectancy  Adult mortality  Infant deaths  \
# 0     Afghanistan  2000           54.800          321.000             88
# 1     Afghanistan  2001           55.300          316.000             88
# 2     Afghanistan  2002           56.200            3.000             88
# 3     Afghanistan  2003           56.700          295.000             87
# 4     Afghanistan  2004           57.000          293.000             87
# ...           ...   ...              ...              ...            ...
# 2440     Zimbabwe  2010           52.400          527.000             29
# 2441     Zimbabwe  2011           54.900          464.000             28
# 2442     Zimbabwe  2012           56.600          429.000             26
# 2443     Zimbabwe  2013           58.000          399.000             25
# 2444     Zimbabwe  2014           59.200          371.000             23
#
#       Alcohol  Percentage expenditure  Hepatitis B  Measles    BMI  Polio  \
# 0       0.010                  10.425       62.000     6532 12.200 24.000
# 1       0.010                  10.575       63.000     8762 12.600 35.000
# 2       0.010                  16.887       64.000     2486 13.000 36.000
# 3       0.010                  11.089       65.000      798 13.400 41.000
# 4       0.020                  15.296       67.000      466 13.800  5.000
# ...       ...                     ...          ...      ...    ...    ...
# 2440    5.210                  53.309        9.000     9696 29.400 89.000
# 2441    6.000                  63.751       94.000        0 29.900 93.000
# 2442    6.090                  92.602       97.000        0  3.300 95.000
# 2443    6.390                  10.667       95.000        0  3.800 95.000
# 2444    6.500                  10.823       91.000        0 31.300 92.000
#
#       Total expenditure  Diphtheria  HIV/AIDS  Thinness 1-19 years  \
# 0                 8.200      24.000     0.100                2.300
# 1                 7.800      33.000     0.100                2.100
# 2                 7.760      36.000     0.100               19.900
# 3                 8.820      41.000     0.100               19.700
# 4                 8.790       5.000     0.100               19.500
# ...                 ...         ...       ...                  ...
# 2440              5.370      89.000    15.700                7.100
# 2441              6.310      93.000    13.300                6.800
# 2442              6.690      95.000     8.800                6.500
# 2443              6.880      95.000     6.800                6.200
# 2444              6.440      91.000     6.300                5.900
#
#       Income composition of resources  Schooling
# 0                               0.338      5.500
# 1                               0.340      5.900
# 2                               0.341      6.200
# 3                               0.373      6.500
# 4                               0.381      6.800
# ...                               ...        ...
# 2440                            0.436     10.000
# 2441                            0.452     10.100
# 2442                            0.464      9.800
# 2443                            0.488     10.400
# 2444                            0.498     10.300
#
# [2445 rows x 17 columns]

# %%
df.skew(axis = 0, numeric_only = True)
# Out:
# Year                               0.000
# Life expectancy                   -0.686
# Adult mortality                    1.221
# Infant deaths                      9.484
# Alcohol                            0.718
# Percentage expenditure             4.732
# Hepatitis B                       -1.438
# Measles                            9.665
# BMI                               -0.214
# Polio                             -2.046
# Total expenditure                  0.390
# Diphtheria                        -2.046
# HIV/AIDS                           5.040
# Thinness 1-19 years                1.659
# Income composition of resources   -1.169
# Schooling                         -0.521
# dtype: float64

# %%
def plot_histogram(data, ylabel, xlabel, title):
    plt.figure(figsize = (10, 6))
    plt.hist(data, edgecolor="white")
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title);
def get_outlier(df, column):
    Q1 = np.percentile(df[column], 25, method='midpoint')
    Q3 = np.percentile(df[column], 75, method='midpoint')
    IQR = Q3 - Q1
    return df[(df[column]>=(Q3+1.5*IQR)) | (df[column]<=(Q1-1.5*IQR))].sort_values(by=[column]).reset_index()

# %%
plot_histogram(df['Infant deaths'], 'Count', 'infant deaths', 'Histogram of Infant deaths')

# %%
sns.boxplot(data=df, x=df['Infant deaths'])
# Out:
# <Axes: xlabel='Infant deaths'>

# %%
outlier = get_outlier(df, 'Infant deaths')[['Country', 'Year', 'Infant deaths']]
outlier
# Out:
#           Country  Year  Infant deaths
# 0    South Africa  2008             50
# 1        Cameroon  2012             50
# 2           Niger  2011             50
# 3           Niger  2010             50
# 4        Cameroon  2011             51
# ..            ...   ...            ...
# 279         India  2004           1600
# 280         India  2002           1700
# 281         India  2003           1700
# 282         India  2000           1800
# 283         India  2001           1800
#
# [284 rows x 3 columns]

# %%
df['Infant deaths'] = np.log(df['Infant deaths'] + 1)
sns.boxplot(data=df, x=df['Infant deaths'])
# #print(df.drop(['Country', 'Status'], axis=1).skew())
# Out:
# <Axes: xlabel='Infant deaths'>

# %%
plot_histogram(df['Percentage expenditure'], 'Count', 'Percentage expenditure', 'Histogram of Percentage expenditure')

# %%
sns.boxplot(data=df, x=df['Percentage expenditure'])
# Out:
# <Axes: xlabel='Percentage expenditure'>

# %%
outlier = get_outlier(df, 'Percentage expenditure')[['Country', 'Year', 'Percentage expenditure']]
outlier
# Out:
#                  Country  Year  Percentage expenditure
# 0                   Oman  2013                1154.893
# 1    Antigua and Barbuda  2003                1158.065
# 2            Netherlands  2012                1162.657
# 3               Suriname  2012                1168.324
# 4             Costa Rica  2006                1185.412
# ..                   ...   ...                     ...
# 295           Luxembourg  2006               15345.491
# 296           Luxembourg  2013               15515.752
# 297           Luxembourg  2014               16255.162
# 298           Luxembourg  2011               17028.528
# 299           Luxembourg  2008               18961.349
#
# [300 rows x 3 columns]

# %%
df['Percentage expenditure'] = np.log(df['Percentage expenditure'] + 1)
sns.boxplot(data=df, x=df['Percentage expenditure'])
# Out:
# <Axes: xlabel='Percentage expenditure'>

# %%
plot_histogram(df['Measles'], 'Count', 'Measles', 'Histogram of Measles')

# %%
sns.boxplot(data=df, x=df['Measles'])
# Out:
# <Axes: xlabel='Measles'>

# %%
outlier = get_outlier(df, 'Measles')[['Country', 'Year', 'Measles']]
outlier
# Out:
#         Country  Year  Measles
# 0    Mauritania  2002      883
# 1         Yemen  2002      890
# 2        Rwanda  2001      896
# 3        Zambia  2012      896
# 4      Cameroon  2003      899
# ..          ...   ...      ...
# 448       China  2005   124219
# 449       China  2008   131441
# 450     Nigeria  2003   141258
# 451     Nigeria  2001   168107
# 452     Nigeria  2000   212183
#
# [453 rows x 3 columns]

# %%
df['Measles'] = np.log(df['Measles'] + 1)
sns.boxplot(data=df, x=df['Measles'])
# Out:
# <Axes: xlabel='Measles'>

# %%
plot_histogram(df['HIV/AIDS'], 'Count', 'HIV/AIDS', 'Histogram of HIV/AIDS')

# %%
sns.boxplot(data=df, x=df['HIV/AIDS'])
# Out:
# <Axes: xlabel='HIV/AIDS'>

# %%
outlier = get_outlier(df, 'HIV/AIDS')[['Country', 'Year', 'HIV/AIDS']]
outlier
# Out:
#           Country  Year  HIV/AIDS
# 0          Angola  2001     2.100
# 1           Benin  2003     2.100
# 2           Benin  2002     2.100
# 3           Benin  2001     2.100
# 4    Sierra Leone  2004     2.100
# ..            ...   ...       ...
# 432     Swaziland  2001    48.800
# 433     Swaziland  2005    49.100
# 434     Swaziland  2002    49.900
# 435     Swaziland  2004    50.300
# 436     Swaziland  2003    50.600
#
# [437 rows x 3 columns]

# %%
df['HIV/AIDS'] = np.log(df['HIV/AIDS'] + 1)
sns.boxplot(data=df, x=df['HIV/AIDS']) #5 loop
# Out:
# <Axes: xlabel='HIV/AIDS'>

# %%
df.skew(axis = 0, numeric_only = True)
# Out:
# Year                               0.000
# Life expectancy                   -0.686
# Adult mortality                    1.221
# Infant deaths                      0.725
# Alcohol                            0.718
# Percentage expenditure            -0.234
# Hepatitis B                       -1.438
# Measles                            0.552
# BMI                               -0.214
# Polio                             -2.046
# Total expenditure                  0.390
# Diphtheria                        -2.046
# HIV/AIDS                           2.075
# Thinness 1-19 years                1.659
# Income composition of resources   -1.169
# Schooling                         -0.521
# dtype: float64

# %%
df.to_csv('Datasets/Kaggle Transformed/Life Expectancy Kaggle Transformed.csv', index=False)
